# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#TED-Talks" data-toc-modified-id="TED-Talks-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>TED Talks</a></span></li><li><span><a href="#Токенизация" data-toc-modified-id="Токенизация-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Токенизация</a></span></li><li><span><a href="#Распределение-слов-по-частоте,-стоп-слова" data-toc-modified-id="Распределение-слов-по-частоте,-стоп-слова-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Распределение слов по частоте, стоп слова</a></span></li><li><span><a href="#Приведение-к-нормальной-форме" data-toc-modified-id="Приведение-к-нормальной-форме-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Приведение к нормальной форме</a></span></li><li><span><a href="#Выделение-коллокаций" data-toc-modified-id="Выделение-коллокаций-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выделение коллокаций</a></span></li><li><span><a href="#TF-IDF" data-toc-modified-id="TF-IDF-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>TF-IDF</a></span><ul class="toc-item"><li><span><a href="#поиск-похожих" data-toc-modified-id="поиск-похожих-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>поиск похожих</a></span></li><li><span><a href="#выделение-ключевых-слов" data-toc-modified-id="выделение-ключевых-слов-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>выделение ключевых слов</a></span></li></ul></li><li><span><a href="#Word2Vec" data-toc-modified-id="Word2Vec-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Word2Vec</a></span><ul class="toc-item"><li><span><a href="#Sentence-Embeddings" data-toc-modified-id="Sentence-Embeddings-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Sentence Embeddings</a></span></li></ul></li><li><span><a href="#Topic-Modeling" data-toc-modified-id="Topic-Modeling-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Topic Modeling</a></span><ul class="toc-item"><li><span><a href="#Поиск-похожих-документов" data-toc-modified-id="Поиск-похожих-документов-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Поиск похожих документов</a></span></li><li><span><a href="#Краткое-описание-документов-(суммаризация)" data-toc-modified-id="Краткое-описание-документов-(суммаризация)-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Краткое описание документов (суммаризация)</a></span></li><li><span><a href="#Визуализация-тематической-модели" data-toc-modified-id="Визуализация-тематической-модели-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Визуализация тематической модели</a></span></li></ul></li></ul></div>

# %% [markdown]
# Uncomment if you are using colab

# %%
# !pip install razdel==0.5
# !pip install pyLDAvis==2.1.2
# !pip install pymorphy2==0.8
# Out:
# Collecting razdel==0.5
#   Downloading razdel-0.5.0-py3-none-any.whl (21 kB)
# Installing collected packages: razdel
# Successfully installed razdel-0.5.0
# Collecting pyLDAvis==2.1.2
#   Downloading pyLDAvis-2.1.2.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 3.2 MB/s eta 0:00:0000:0100:010m
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wheel>=0.23.0 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pyLDAvis==2.1.2) (0.38.4)
# Requirement already satisfied: numpy>=1.9.2 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pyLDAvis==2.1.2) (1.23.5)
# Requirement already satisfied: scipy>=0.18.0 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pyLDAvis==2.1.2) (1.10.0)
# Requirement already satisfied: pandas>=0.17.0 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pyLDAvis==2.1.2) (1.5.3)
# Requirement already satisfied: joblib>=0.8.4 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pyLDAvis==2.1.2) (1.1.1)
# Requirement already satisfied: jinja2>=2.7.2 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pyLDAvis==2.1.2) (3.1.2)
# Requirement already satisfied: numexpr in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pyLDAvis==2.1.2) (2.8.4)
# Requirement already satisfied: pytest in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pyLDAvis==2.1.2) (7.1.2)
# Requirement already satisfied: future in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pyLDAvis==2.1.2) (0.18.3)
# Collecting funcy
#   Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from jinja2>=2.7.2->pyLDAvis==2.1.2) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pandas>=0.17.0->pyLDAvis==2.1.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pandas>=0.17.0->pyLDAvis==2.1.2) (2022.7)
# Requirement already satisfied: attrs>=19.2.0 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pytest->pyLDAvis==2.1.2) (22.1.0)
# Requirement already satisfied: iniconfig in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pytest->pyLDAvis==2.1.2) (1.1.1)
# Requirement already satisfied: packaging in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pytest->pyLDAvis==2.1.2) (22.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pytest->pyLDAvis==2.1.2) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pytest->pyLDAvis==2.1.2) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from pytest->pyLDAvis==2.1.2) (2.0.1)
# Requirement already satisfied: six>=1.5 in /Users/k.shematorov/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=0.17.0->pyLDAvis==2.1.2) (1.16.0)
# Building wheels for collected packages: pyLDAvis
#   Building wheel for pyLDAvis (setup.py) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-2.1.2-py2.py3-none-any.whl size=97722 sha256=3ac4014796a89c52fce6f3d6b835279b80ebafec195ce6ee28fcd369602872d3
#   Stored in directory: /Users/k.shematorov/Library/Caches/pip/wheels/48/86/5e/c5b06291c3a932ca009936e87a14e4c2defb77797aaadabe16
# Successfully built pyLDAvis
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-2.0 pyLDAvis-2.1.2
# Collecting pymorphy2==0.8
#   Downloading pymorphy2-0.8-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 295.2 kB/s eta 0:00:00a 0:00:01
# Collecting dawg-python>=0.7
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting pymorphy2-dicts<3.0,>=2.4
#   Downloading pymorphy2_dicts-2.4.393442.3710985-py2.py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 6.5 MB/s eta 0:00:0000:0100:01
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=30767f943e378d6cc0d1f3f991d1cb999a7cb800f12431ee6af7d67fbcf130d2
#   Stored in directory: /Users/k.shematorov/Library/Caches/pip/wheels/7c/d7/8d/2156234738063e3d4a39ba77dc677046100e62766b53807189
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts, docopt, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.8 pymorphy2-dicts-2.4.393442.3710985

# %%
import warnings
warnings.filterwarnings('ignore')

import re
from collections import Counter

import razdel
import nltk
nltk.download('stopwords')
import pymorphy2
import gensim
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import plotly
from tqdm import tqdm_notebook
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import normalize
from sklearn.metrics.pairwise import cosine_similarity
import pyLDAvis
import pyLDAvis.gensim

from IPython.display import YouTubeVideo
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/k.shematorov/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
DATA_PATH = 'data/ted_talks.csv.gz'

# %%
# !gunzip $DATA_PATH

# %%
SEED = 42
np.random.seed(SEED)

TOKEN_PATTERN = "[а-яё]+"

DATA_PATH = 'data/ted_talks.csv'

# %% [markdown]
# Uncomment if you are using colab

# %%
#!mkdir ./data
#!wget https://raw.githubusercontent.com/vadim0912/MLIntro2022_Spring/master/lecture06/data/ted_talks.csv.gz -O $DATA_PATH

# %% [markdown]
# # TED Talks

# %%
df = pd.read_csv(DATA_PATH)

df.head()
# Out:
#                                                 talk  \
# 0            jonas_gahr_store_in_defense_of_dialogue
# 1     iwan_baan_ingenious_homes_in_unexpected_places
# 2  melinda_french_gates_what_nonprofits_can_learn...
# 3                 dean_kamen_on_inventing_and_giving
# 4                 bruno_maisonnier_dance_tiny_robots
#
#                                                 text
# 0  Среди всех дефицитов , беспокоящих нас сегодня...
# 1  Мне крупно везло на протяжении всей моей карье...
# 2  Больше всего я люблю в моей работе в Фонде Гей...
# 3  Как уже было замечено , каждый раз , приходя с...
# 4  ( Механические шумы ) ( Музыка ) ( Аплодисменты )

# %%
df.shape
# Out:
# (2093, 2)

# %%
df.text.str.len().hist(bins=200);

# %%
min_talk_len = 750

df = df[df.text.str.len() >= min_talk_len].reset_index(drop=True)

df.text.str.len().hist(bins=200);

# %%
df.shape
# Out:
# (1929, 2)

# %%
corpus = df.text.values

# %% [markdown]
# # Токенизация

# %%
sentence = "Как же так?! Олег... Мы же в 18.00 договаривались встретиться:("

print(sentence.split())
# Out:
# ['Как', 'же', 'так?!', 'Олег...', 'Мы', 'же', 'в', '18.00', 'договаривались', 'встретиться:(']

# %%
print(re.findall("[а-яА-ЯёЁ]+", sentence))
# Out:
# ['Как', 'же', 'так', 'Олег', 'Мы', 'же', 'в', 'договаривались', 'встретиться']

# %%
print(re.split(r"[-\s.,;!?]+", sentence))
# Out:
# ['Как', 'же', 'так', 'Олег', 'Мы', 'же', 'в', '18', '00', 'договаривались', 'встретиться:(']

# %%
print([token.text for token in razdel.tokenize(sentence)])
# Out:
# ['Как', 'же', 'так', '?!', 'Олег', '...', 'Мы', 'же', 'в', '18.00', 'договаривались', 'встретиться', ':(']

# %%
print(nltk.tokenize.casual_tokenize(sentence))
# Out:
# ['Как', 'же', 'так', '?', '!', 'Олег', '...', 'Мы', 'же', 'в', '18.00', 'договаривались', 'встретиться', ':(']

# %%
corpus[0]
# Out:
# 'Среди всех дефицитов , беспокоящих нас сегодня — прежде всего финансового и экономического — меня больше всего волнует дефицит политического диалога : нашей способности реагировать на современные конфликты в их настоящем виде , осознавать , что лежит в их основе , кто является ключевыми игроками , и как с ними работать . Мы , дипломаты , обучены работать с конфликтами и спорами между государствами . И , поверьте , работы нам хватает . Торговля , разоружение , международные отношения . Но картина меняется , и мы видим , что на сцену выходят новые ключевые игроки . Мы пренебрежительно называем их « группы » . Они представляют социальные , религиозные , политические , экономические и военные реалии . И мы изо всех сил стараемся понять , как с ними работать . Правила вступления в переговоры : как говорить , когда говорить , как найти общий язык . Позвольте показать вам график , который отражает характер конфликтов с 1946 года по сегодняшний день . Зелёный цвет — традиционные межгосударственные конфликты , о которых мы привыкли читать в газетах . Красный — современные конфликты , конфликты внутри государств . Они довольно многообразны и находятся вне понимания современной дипломатии . И главными среди этих ключевых игроков являются группы , представляющие различные интересы внутри страны . Их методы быстро перенимаются в других странах . Так что это касается всех . Ещё одно наблюдение , которые мы сделали совсем недавно , состоит в том , что очень немногие из этих меж- и внутригосударственных конфликтов могут быть решены применением военной силы . Возможно использование военных методов , но решить проблему таким путём не получится . Необходимы политические решения . И здесь мы сталкиваемся с проблемой , так как это вне традиционной дипломатии . И среди государств чувствуется нежелание с этим работать . К тому же , последние десять лет ситуация была такова , что взаимодействие с этими группами было опасно на идейном и политическом уровне . После теракта 11-го сентября вы или с нами , или против нас . Чёрное или белое . И довольно часто такие группы немедленно объявлялись террористическими . Кто будет вести переговоры с террористами ? Запад , с моей точки зрения , за это десятилетие потерял свои позиции , так как не понимал эти группы . Мы потратили больше времени на то , чтобы объяснить , почему мы не должны говорить с ними , чем на то , чтобы найти контакт . Я не наивен . Мы не можем всё время со всеми разговаривать . Иногда от этого надо уходить . Иногда необходимо и военное вмешательство . Я считаю , что в Ливии это было необходимо , как и в Афганистане . Моя страна рассчитывает на свою безопасность , основываясь на военно-политическом блоке , это понятно . Но всё же у нас огромная нехватка опыта в разрешении и понимании современных конфликтов . Давайте обратимся к Афганистану . 10 лет спустя военного вмешательства эта страна всё ещё далека от спокойствия . Ситуация , если быть честным , очень серьёзная . Опять же , военное вмешательство необходимо , но не решает проблему . Когда впервые в 2005 году я приехал в Афганистан в качестве министра иностранных дел , я встретился с командиром ISAF , многонациональных сил . Он мне сказал : « Министр , победа может быть одержана военными средствами . Нам лишь необходимо и дальше стоять на своём » . Сейчас уже четыре командующих ISAF сменились , и мы слышим другие заявления : « Одержать победу военными методами невозможно . Военное присутствие необходимо , но необходимо подключить политику . Возможно только политическое решение . И найти это решение должны не мы , а афганцы » . Но тогда необходима другая политическая обстановка , отличная от сложившейся в 2001-м и 2002-м . Необходима политика участия , при которой члены этого крайне сложного общества смогут сами решать свои проблемы . И вроде бы все с этим согласны . Это был спорный вопрос три , четыре , пять лет назад . Сегодня все согласны . Но сейчас , когда мы готовы к разговору , мы осознаем , как мало мы знаем . Потому что мы не разг ...

# %%
def tokenize(text):
    return re.findall(TOKEN_PATTERN, text.lower())

docs = [tokenize(text) for text in corpus]

# %%
docs[0]
# Out:
# ['среди',
#  'всех',
#  'дефицитов',
#  'беспокоящих',
#  'нас',
#  'сегодня',
#  'прежде',
#  'всего',
#  'финансового',
#  'и',
#  'экономического',
#  'меня',
#  'больше',
#  'всего',
#  'волнует',
#  'дефицит',
#  'политического',
#  'диалога',
#  'нашей',
#  'способности',
#  'реагировать',
#  'на',
#  'современные',
#  'конфликты',
#  'в',
#  'их',
#  'настоящем',
#  'виде',
#  'осознавать',
#  'что',
#  'лежит',
#  'в',
#  'их',
#  'основе',
#  'кто',
#  'является',
#  'ключевыми',
#  'игроками',
#  'и',
#  'как',
#  'с',
#  'ними',
#  'работать',
#  'мы',
#  'дипломаты',
#  'обучены',
#  'работать',
#  'с',
#  'конфликтами',
#  'и',
#  'спорами',
#  'между',
#  'государствами',
#  'и',
#  'поверьте',
#  'работы',
#  'нам',
#  'хватает',
#  'торговля',
#  'разоружение',
#  'международные',
#  'отношения',
#  'но',
#  'картина',
#  'меняется',
#  'и',
#  'мы',
#  'видим',
#  'что',
#  'на',
#  'сцену',
#  'выходят',
#  'новые',
#  'ключевые',
#  'игроки',
#  'мы',
#  'пренебрежительно',
#  'называем',
#  'их',
#  'группы',
#  'они',
#  'представляют',
#  'социальные',
#  'религиозные',
#  'политические',
#  'экономические',
#  'и',
#  'военные',
#  'реалии',
#  'и',
#  'мы',
#  'изо',
#  'всех',
#  'сил',
#  'стараемся',
#  'понять',
#  'как',
#  'с',
#  'ними',
#  'работать',
#  'правила',
#  'вступления',
#  'в',
#  'переговоры',
#  'как',
#  'говорить',
#  'когда',
#  'говорить',
#  'как',
#  'найти',
#  'общий',
#  'язык',
#  'позвольте',
#  'показать',
#  'вам',
#  'график',
#  'который',
#  'отражает',
#  'характер',
#  'конфликтов',
#  'с',
#  'года',
#  'по',
#  'сегодняшний',
#  'день',
#  'зелёный',
#  'цвет',
#  'традиционные',
#  'межгосударственные',
#  'конфликты',
#  'о',
#  'которых',
#  'мы',
#  'привыкли',
#  'читать',
#  'в',
#  'газетах',
#  'красный',
#  'современные',
#  'конфликты',
#  'конфликты',
#  'внутри',
#  'государств',
#  'они',
#  'довольно',
#  'многообразны',
#  'и',
#  'находятся',
#  'вне',
#  'понимания',
#  'современной',
#  'дипломатии',
#  'и',
#  'главными',
#  'среди',
#  'этих',
#  'ключевых',
#  'игроков',
#  'являются',
#  'группы',
#  'представляющие',
#  'различные',
#  'интересы',
#  'внутри',
#  'страны',
#  'их',
#  'методы',
#  'быстро',
#  'перенимаются',
#  'в',
#  'других',
#  'странах',
#  'так',
#  'что',
#  'это',
#  'касается',
#  'всех',
#  'ещё',
#  'одно',
#  'наблюдение',
#  'которые',
#  'мы',
#  'сделали',
#  'совсем',
#  'недавно',
#  'состоит',
#  'в',
#  'том',
#  'что',
#  'очень',
#  'немногие',
#  'из',
#  'этих',
#  'меж',
#  'и',
#  'внутригосударственных',
#  'конфликтов',
#  'могут',
#  'быть',
#  'решены',
#  'применением',
#  'военной',
#  'силы',
#  'возможно',
#  'использование',
#  'военных',
#  'методов',
#  'но',
#  'решить',
#  'проблему',
#  'таким',
#  'путём',
#  'не',
#  'получится',
#  'необходимы',
#  'политические',
#  'решения',
#  'и',
#  'здесь',
#  'мы',
#  'сталкиваемся',
#  'с',
#  'проблемой',
#  'так',
#  'как',
#  'это',
#  'вне',
#  'традиционной',
#  'дипломатии',
#  'и',
#  'среди',
#  'государств',
#  'чувствуется',
#  'нежелание',
#  'с',
#  'этим',
#  'работать',
#  'к',
#  'тому',
#  'же',
#  'последние',
#  'десять',
#  'лет',
#  'ситуация',
#  'была',
#  'такова',
#  'что',
#  'взаимодействие',
#  'с',
#  'этими',
#  'группами',
#  'было',
#  'опасно',
#  'на',
#  'идейном',
#  'и',
#  'политическом',
#  'уровне',
#  'после',
#  'теракта',
#  'го',
#  'сентября',
#  'вы',
#  'или',
#  'с',
#  'нами',
#  'или',
#  'против',
#  'нас',
#  'чёрное',
#  'или',
#  'белое',
#  'и',
#  'довольно',
#  'часто',
#  'такие',
#  'группы',
#  'немедленно',
#  'объявлялись',
#  'террористическими',
#  'кто',
#  'будет',
#  'вести',
#  'переговоры',
#  'с',
#  'террористами',
#  'запад',
#  'с',
#  'моей',
#  'точки',
#  'зрения',
#  'за',
#  'это',
#  'десятилетие',
#  'потерял',
#  'свои',
#  'позиции',
#  'так',
#  'как',
#  'не',
#  'понимал',
#  'эти',
#  'группы',
#  'мы',
#  'потратили',
#  'больше',
#  'времени',
#  'на',
#  'то',
#  'чтобы',
#  'объяснить',
#  'почему',
#  'мы',
#  'не',
#  'должны',
#  'говорить',
#  'с',
#  'ними',
#  'чем',
#  'на',
#  'то',
#  'чтобы',
#  'найти',
#  'контакт',
#  'я',
#  'не',
#  'наивен',
#  'мы',
#  'не',
#  'можем',
#  'всё',
#  'время',
#  'со',
#  'всеми',
#  'разговаривать',
#  'иногда',
#  'от',
#  'этого',
#  'надо',
#  'уходить',
#  'иногда',
#  'необходимо',
#  'и',
#  'военное',
#  'вмешательство',
#  'я',
#  'считаю',
#  'что',
#  'в',
#  'ливии',
#  'это',
#  'было',
#  'необходимо',
#  'как',
#  'и',
#  'в',
#  'афганистане',
#  'моя',
#  'страна',
#  'рассчитывает',
#  'на',
#  'свою',
#  'безопасность',
#  'основываясь',
#  'на',
#  'военно',
#  'политическом',
#  'блоке',
#  'это',
#  'понятно',
#  'но',
#  'всё',
#  'же',
#  'у',
#  'нас',
#  'огромная',
#  'нехватка',
#  'опыта',
#  'в',
#  'разрешении',
#  'и',
#  'понимании',
#  'современных',
#  'конфликтов',
#  'давайте',
#  'обратимся',
#  'к',
#  'афганистану',
#  'лет',
#  'спустя',
#  'военного',
#  'вмешательства',
#  'эта',
#  'страна',
#  'всё',
#  'ещё',
#  'далека',
#  'от',
#  'спокойствия',
#  'ситуация',
#  'если',
#  'быть',
#  'честным',
#  'очень',
#  'серьёзная',
#  'опять',
#  'же',
#  'военное',
#  'вмешательство',
#  'необходимо',
#  'но',
#  'не',
#  'решает',
#  'проблему',
#  'когда',
#  'впервые',
#  'в',
#  'году',
#  'я',
#  'приехал',
#  'в',
#  'афганистан',
#  'в',
#  'качестве',
#  'министра',
#  'иностранных',
#  'дел',
#  'я',
#  'встретился',
#  'с',
#  'командиром',
#  'многонациональных',
#  'сил',
#  'он',
#  'мне',
#  'сказал',
#  'министр',
#  'победа',
#  'может',
#  'быть',
#  'одержана',
#  'военными',
#  'средствами',
#  'нам',
#  'лишь',
#  'необходимо',
#  'и',
#  'дальше',
#  'стоять',
#  'на',
#  'своём',
#  'сейчас',
#  'уже',
#  'четыре',
#  'командующих',
#  'сменились',
#  'и',
#  'мы',
#  'слышим',
#  'другие',
#  'заявления',
#  'одержать',
#  'победу',
#  'военными',
#  'методами',
#  'невозможно',
#  'военное',
#  'присутствие',
#  'необходимо',
#  'но',
#  'необходимо',
#  'подключить',
#  'политику',
#  'возможно',
#  'только',
#  'политическое',
#  'решение',
#  'и',
#  'найти',
#  'это',
#  'решение',
#  'должны',
#  'не',
#  'мы',
#  'а',
#  'афганцы',
#  'но',
#  'тогда',
#  'необходима',
#  'другая',
#  'политическая',
#  'обстановка',
#  'отличная',
#  'от',
#  'сложившейся',
#  'в',
#  'м',
#  'и',
#  'м',
#  'необходима',
#  'политика',
#  'участия',
#  'при',
#  'которой',
#  'члены',
#  'этого',
#  'крайне',
#  'сложного',
#  'общества',
#  'смогут',
#  'сами',
#  'решать',
#  'свои',
#  'проблемы',
#  'и',
#  'вроде',
#  'бы',
#  'все',
#  'с',
#  'этим',
#  'согласны',
#  'это',
#  'был',
#  'спорный',
#  'вопрос',
#  'три',
#  'четыре',
#  'пять',
#  'лет',
#  'назад',
#  'сегодня',
#  'все',
#  'согласны',
#  'но',
#  'сейчас',
#  'когда',
#  'мы',
#  'готовы',
#  'к',
#  'разговору',
#  'мы',
#  'осознаем',
#  'как',
#  'мало',
#  'мы',
#  'знаем',
#  'потому',
#  'что',
#  'мы',
#  'не',
#  'разговаривали',
#  'мы',
#  'не',
#  'понимали',
#  'что',
#  'происходило',
#  'международный',
#  'комитет',
#  'красного',
#  'креста',
#  'мккк',
#  'ведёт',
#  'переговоры',
#  'со',
#  'всеми',
#  'потому',
#  'что',
#  'он',
#  'нейтрален',
#  'и',
#  'это',
#  'одна',
#  'из',
#  'причин',
#  'почему',
#  'эта',
#  'организация',
#  'возможно',
#  'является',
#  'наиболее',
#  'информированным',
#  'и',
#  'разбирающимся',
#  'в',
#  'современных',
#  'конфликтах',
#  'игроком',
#  'потому',
#  'что',
#  'они',
#  'разговаривают',
#  'я',
#  'считаю',
#  'не',
#  'обязательно',
#  'быть',
#  'нейтральным',
#  'чтобы',
#  'разговаривать',
#  'и',
#  'не',
#  'обязательно',
#  'соглашаться',
#  'когда',
#  'вы',
#  'садитесь',
#  'за',
#  'стол',
#  'переговоров',
#  'и',
#  'всегда',
#  'можно',
#  'прервать',
#  'переговоры',
#  'но',
#  'если',
#  'вы',
#  'не',
#  'разговариваете',
#  'невозможно',
#  'привлечь',
#  'и',
#  'другую',
#  'сторону',
#  'и',
#  'та',
#  'другая',
#  'сторона',
#  'которую',
#  'вы',
#  'собираетесь',
#  'привлечь',
#  'к',
#  'переговорам',
#  'как',
#  'раз',
#  'тот',
#  'оппонент',
#  'с',
#  'которым',
#  'вы',
#  'в',
#  'корне',
#  'не',
#  'согласны',
#  'на',
#  'подписании',
#  'соглашения',
#  'в',
#  'осло',
#  'премьер',
#  'министр',
#  'рабин',
#  'сказал',
#  'вы',
#  'не',
#  'заключаете',
#  'мир',
#  'со',
#  'своими',
#  'друзьями',
#  'вы',
#  'заключаете',
#  'мир',
#  'с',
#  'врагами',
#  'это',
#  'тяжело',
#  'но',
#  'необходимо',
#  'позвольте',
#  'мне',
#  'продолжить',
#  'это',
#  'площадь',
#  'тахрир',
#  'революция',
#  'в',
#  'разгаре',
#  'арабская',
#  'весна',
#  'перетекает',
#  'в',
#  'осень',
#  'а',
#  'затем',
#  'в',
#  'зиму',
#  'это',
#  'будет',
#  'длиться',
#  'ещё',
#  'долгое',
#  'долгое',
#  'время',
#  'и',
#  'кто',
#  'знает',
#  'как',
#  'это',
#  'будет',
#  'называться',
#  'в',
#  'конце',
#  'но',
#  'не',
#  'это',
#  'важно',
#  'важно',
#  'то',
#  'что',
#  'возможно',
#  'мы',
#  'наблюдаем',
#  'первую',
#  'в',
#  'истории',
#  'арабского',
#  'мира',
#  'революцию',
#  'снизу',
#  'революцию',
#  'народа',
#  'социальные',
#  'группы',
#  'выходят',
#  'на',
#  'улицы',
#  'а',
#  'мы',
#  'на',
#  'западе',
#  'осознали',
#  'что',
#  'обладаем',
#  'очень',
#  'небольшими',
#  'знаниями',
#  'о',
#  'происходящем',
#  'потому',
#  'что',
#  'мы',
#  'никогда',
#  'не',
#  'разговаривали',
#  'с',
#  'людьми',
#  'в',
#  'этих',
#  'странах',
#  'большинство',
#  'правительств',
#  'следуют',
#  'диктату',
#  'авторитарных',
#  'лидеров',
#  'держаться',
#  'подальше',
#  'от',
#  'различных',
#  'групп',
#  'так',
#  'как',
#  'они',
#  'являются',
#  'террористами',
#  'и',
#  'сейчас',
#  'когда',
#  'они',
#  'выходят',
#  'на',
#  'улицы',
#  'и',
#  'мы',
#  'приветствуем',
#  'демократическую',
#  'революцию',
#  'мы',
#  'понимаем',
#  'как',
#  'мало',
#  'знаем',
#  'на',
#  'данный',
#  'момент',
#  'все',
#  'ещё',
#  'продолжается',
#  'дискуссия',
#  'следует',
#  'ли',
#  'нам',
#  'вести',
#  'переговоры',
#  'с',
#  'братьями',
#  'мусульманами',
#  'следует',
#  'ли',
#  'разговаривать',
#  'с',
#  'хамасом',
#  'ведь',
#  'если',
#  'мы',
#  'так',
#  'поступим',
#  'мы',
#  'легитимируем',
#  'их',
#  'я',
#  'считаю',
#  'это',
#  'ошибочным',
#  'если',
#  'вести',
#  'переговоры',
#  'в',
#  'правильном',
#  'ключе',
#  'то',
#  'можно',
#  'ясно',
#  'дать',
#  'понять',
#  'разговаривать',
#  'не',
#  'значит',
#  'соглашаться',
#  'и',
#  'как',
#  'мы',
#  'можем',
#  'заявить',
#  'братьям',
#  'мусульманам',
#  'что',
#  'нам',
#  'и',
#  'следует',
#  'сделать',
#  'что',
#  'они',
#  'обязаны',
#  'уважать',
#  'права',
#  'меньшинства',
#  'если',
#  'мы',
#  'не',
#  'принимаем',
#  'прав',
#  'большинства',
#  'ведь',
#  'они',
#  'могут',
#  'перерасти',
#  'в',
#  'большинство',
#  'как',
#  'нам',
#  'избежать',
#  'двойных',
#  'стандартов',
#  'если',
#  'мы',
#  'пропагандируем',
#  'демократию',
#  'и',
#  'одновременно',
#  'не',
#  'желаем',
#  'общаться',
#  'с',
#  'группами',
#  'представляющими',
#  'интересы',
#  'народа',
#  'сможем',
#  'ли',
#  'мы',
#  'когда',
#  'нибудь',
#  'сесть',
#  'за',
#  'стол',
#  'переговоров',
#  'сейчас',
#  'мои',
#  'подчинённые',
#  'проинструктированы',
#  'вести',
#  'переговоры',
#  'со',
#  'всеми',
#  'этими',
#  'группами',
#  'но',
#  'переговоры',
#  'можно',
#  'вести',
#  'по',
#  'разному',
#  'мы',
#  'разграничиваем',
#  'их',
#  'на',
#  'переговоры',
#  'на',
#  'дипломатическом',
#  'и',
#  'политическом',
#  'уровне',
#  'сегодня',
#  'переговоры',
#  'могут',
#  'иметь',
#  'своей',
#  'целью',
#  'помощь',
#  'а',
#  'могут',
#  'и',
#  'не',
#  'иметь',
#  'могут',
#  'иметь',
#  'своей',
#  'целью',
#  'участие',
#  'а',
#  'могут',
#  'и',
#  'не',
#  'иметь',
#  'существует',
#  'масса',
#  'способов',
#  'как',
#  'с',
#  'этим',
#  'работать',
#  'если',
#  'мы',
#  'сейчас',
#  'откажемся',
#  'от',
#  'переговоров',
#  'с',
#  'этими',
#  'новыми',
#  'группами',
#  'которые',
#  'будут',
#  'главной',
#  'темой',
#  'в',
#  'новостях',
#  'на',
#  'протяжении',
#  'многих',
#  'лет',
#  'мы',
#  'только',
#  'усугубим',
#  'ситуацию',
#  'на',
#  'мой',
#  'взгляд',
#  'и',
#  'отказаться',
#  'от',
#  'насилия',
#  'в',
#  'пользу',
#  'политики',
#  'будет',
#  'намного',
#  'сложнее',
#  'если',
#  'мы',
#  'не',
#  'сможем',
#  'показать',
#  'этим',
#  'людям',
#  'что',
#  'если',
#  'вы',
#  'идёте',
#  'навстречу',
#  'демократии',
#  'если',
#  'вы',
#  'стремитесь',
#  'к',
#  'нормальным',
#  'и',
#  ...]

# %% [markdown]
# # Распределение слов по частоте, стоп слова

# %% [markdown]
# Постройте словарь `слово` -> `количество вхождений в корпус`

# %%
occurence = Counter([token for doc in docs for token in doc])

# %%
len(occurence)
# Out:
# 152238

# %% [markdown]
# в словаре больше 150 тыс. слов, хотя в литературном русском около 150 тыс.

# %%
occurence.most_common(20)
# Out:
# [('и', 99066),
#  ('в', 88906),
#  ('что', 60461),
#  ('я', 49177),
#  ('это', 48070),
#  ('на', 41620),
#  ('не', 41373),
#  ('мы', 39265),
#  ('с', 27817),
#  ('как', 25721),
#  ('но', 20070),
#  ('то', 19166),
#  ('вы', 18144),
#  ('они', 17174),
#  ('из', 16846),
#  ('для', 14977),
#  ('а', 14539),
#  ('так', 14122),
#  ('у', 13393),
#  ('к', 13322)]

# %% [markdown]
# Самые частые слова относятся к служебным частям речи и несут мало полезной информации. Их можно отбрасывать с помощью подготовленных списков

# %%
stopword_set = set(nltk.corpus.stopwords.words('russian'))
# stopword_set = stopword_set.union({'это', 'который', 'весь', 'наш', 'свой', 'ещё', 'её', 'ваш', 'также', 'итак'})

# %%
stopword_set
# Out:
# {'а',
#  'без',
#  'более',
#  'больше',
#  'будет',
#  'будто',
#  'бы',
#  'был',
#  'была',
#  'были',
#  'было',
#  'быть',
#  'в',
#  'вам',
#  'вас',
#  'вдруг',
#  'ведь',
#  'во',
#  'вот',
#  'впрочем',
#  'все',
#  'всегда',
#  'всего',
#  'всех',
#  'всю',
#  'вы',
#  'где',
#  'да',
#  'даже',
#  'два',
#  'для',
#  'до',
#  'другой',
#  'его',
#  'ее',
#  'ей',
#  'ему',
#  'если',
#  'есть',
#  'еще',
#  'ж',
#  'же',
#  'за',
#  'зачем',
#  'здесь',
#  'и',
#  'из',
#  'или',
#  'им',
#  'иногда',
#  'их',
#  'к',
#  'как',
#  'какая',
#  'какой',
#  'когда',
#  'конечно',
#  'кто',
#  'куда',
#  'ли',
#  'лучше',
#  'между',
#  'меня',
#  'мне',
#  'много',
#  'может',
#  'можно',
#  'мой',
#  'моя',
#  'мы',
#  'на',
#  'над',
#  'надо',
#  'наконец',
#  'нас',
#  'не',
#  'него',
#  'нее',
#  'ней',
#  'нельзя',
#  'нет',
#  'ни',
#  'нибудь',
#  'никогда',
#  'ним',
#  'них',
#  'ничего',
#  'но',
#  'ну',
#  'о',
#  'об',
#  'один',
#  'он',
#  'она',
#  'они',
#  'опять',
#  'от',
#  'перед',
#  'по',
#  'под',
#  'после',
#  'потом',
#  'потому',
#  'почти',
#  'при',
#  'про',
#  'раз',
#  'разве',
#  'с',
#  'сам',
#  'свою',
#  'себе',
#  'себя',
#  'сейчас',
#  'со',
#  'совсем',
#  'так',
#  'такой',
#  'там',
#  'тебя',
#  'тем',
#  'теперь',
#  'то',
#  'тогда',
#  'того',
#  'тоже',
#  'только',
#  'том',
#  'тот',
#  'три',
#  'тут',
#  'ты',
#  'у',
#  'уж',
#  'уже',
#  'хорошо',
#  'хоть',
#  'чего',
#  'чем',
#  'через',
#  'что',
#  'чтоб',
#  'чтобы',
#  'чуть',
#  'эти',
#  'этого',
#  'этой',
#  'этом',
#  'этот',
#  'эту',
#  'я'}

# %%
max_rank = 40_000

counts = [count for _, count in occurence.most_common()[:max_rank]]

plt.plot(range(1, len(counts) + 1), counts)
plt.title('log-log scale', fontsize=18)
plt.yscale('log')
plt.xscale('log')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('rank', fontsize=16)
plt.ylabel('count', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Приведение к нормальной форме

# %%
sorted_tokens = sorted(occurence.keys())

# %%
sorted_tokens
# Out:
# ['а',
#  'аа',
#  'ааа',
#  'аааа',
#  'ааааа',
#  'ааааааааа',
#  'аааааааах',
#  'аааав',
#  'ааарон',
#  'аази',
#  'аакаш',
#  'аарон',
#  'аарона',
#  'аароном',
#  'аарону',
#  'аб',
#  'аба',
#  'абаей',
#  'абажур',
#  'абажура',
#  'абажуром',
#  'абайа',
#  'абайю',
#  'абалон',
#  'абалона',
#  'абани',
#  'абача',
#  'аббас',
#  'аббатства',
#  'аббатство',
#  'абби',
#  'аббревиатур',
#  'аббревиатура',
#  'аббревиатуре',
#  'аббревиатурой',
#  'аббревиатуру',
#  'аббревиатуры',
#  'абдалла',
#  'абдаллы',
#  'абделлахи',
#  'абдель',
#  'абдельрахмана',
#  'абди',
#  'абдубакар',
#  'абдул',
#  'абдула',
#  'абдуразак',
#  'абдуразака',
#  'абдуррахман',
#  'абеба',
#  'абебе',
#  'абебы',
#  'абед',
#  'абеда',
#  'абеде',
#  'абедом',
#  'абеду',
#  'абелом',
#  'абенд',
#  'абердин',
#  'абердине',
#  'абернати',
#  'абзац',
#  'абзаца',
#  'абзацах',
#  'абзаце',
#  'абзацев',
#  'абзацы',
#  'абзуг',
#  'абигейл',
#  'абиджан',
#  'абиджана',
#  'абидин',
#  'абиссинского',
#  'абитуриентам',
#  'абитуриентами',
#  'абитуриентов',
#  'аблеизма',
#  'абляцию',
#  'аболиционистов',
#  'аболиционисты',
#  'абололо',
#  'абонемент',
#  'абонементу',
#  'абонент',
#  'абонента',
#  'абонентам',
#  'абонентов',
#  'абонентская',
#  'абонентской',
#  'абориген',
#  'аборигенам',
#  'аборигенами',
#  'аборигенке',
#  'аборигенки',
#  'аборигенную',
#  'аборигенных',
#  'аборигенов',
#  'аборигены',
#  'аборт',
#  'аборта',
#  'абортам',
#  'абортах',
#  'аборте',
#  'абортных',
#  'абортов',
#  'аборты',
#  'абраама',
#  'абракадабра',
#  'абракадабру',
#  'абракадабры',
#  'абрамс',
#  'абрахама',
#  'абрахаме',
#  'абрахамс',
#  'абреу',
#  'абриком',
#  'абрикоса',
#  'абрис',
#  'абс',
#  'абсента',
#  'абсолюных',
#  'абсолют',
#  'абсолютен',
#  'абсолютизацией',
#  'абсолютизм',
#  'абсолютна',
#  'абсолютная',
#  'абсолютнейшим',
#  'абсолютно',
#  'абсолютного',
#  'абсолютное',
#  'абсолютной',
#  'абсолютном',
#  'абсолютную',
#  'абсолютны',
#  'абсолютные',
#  'абсолютный',
#  'абсолютным',
#  'абсолютными',
#  'абсолютных',
#  'абсорбент',
#  'абсорбента',
#  'абсорбирует',
#  'абсорбируется',
#  'абсорбируют',
#  'абстрагировали',
#  'абстрагировании',
#  'абстрагироваться',
#  'абстрагирую',
#  'абстрагируясь',
#  'абстрактен',
#  'абстрактна',
#  'абстрактная',
#  'абстрактнее',
#  'абстрактно',
#  'абстрактного',
#  'абстрактное',
#  'абстрактной',
#  'абстрактном',
#  'абстрактному',
#  'абстрактности',
#  'абстрактную',
#  'абстрактны',
#  'абстрактные',
#  'абстрактный',
#  'абстрактным',
#  'абстрактными',
#  'абстрактных',
#  'абстракцией',
#  'абстракции',
#  'абстракцию',
#  'абстракция',
#  'абстракциям',
#  'абстракциями',
#  'абстракциях',
#  'абсурд',
#  'абсурда',
#  'абсурден',
#  'абсурдизм',
#  'абсурдистское',
#  'абсурдна',
#  'абсурдная',
#  'абсурдно',
#  'абсурдное',
#  'абсурдной',
#  'абсурдности',
#  'абсурдность',
#  'абсурдную',
#  'абсурдны',
#  'абсурдные',
#  'абсурдным',
#  'абсурдных',
#  'абсурдом',
#  'абсцисс',
#  'абу',
#  'абуджа',
#  'абуди',
#  'абузаида',
#  'абул',
#  'абхаказацки',
#  'ав',
#  'аваз',
#  'аваза',
#  'авалокитешвара',
#  'авалокитешвары',
#  'авалона',
#  'авангард',
#  'авангарде',
#  'авангардизм',
#  'авангардистом',
#  'авангардной',
#  'авангардную',
#  'авангардным',
#  'аванпостом',
#  'аванса',
#  'авансом',
#  'авансцена',
#  'авансценой',
#  'авансцену',
#  'авансцены',
#  'авантюра',
#  'авантюрам',
#  'авантюрист',
#  'авантюристами',
#  'авантюристов',
#  'авантюристы',
#  'авантюрны',
#  'авантюрными',
#  'авантюры',
#  'аварией',
#  'аварии',
#  'аварий',
#  'аварийку',
#  'аварийная',
#  'аварийно',
#  'аварийного',
#  'аварийной',
#  'аварийную',
#  'аварийные',
#  'аварийный',
#  'аварийных',
#  'аварию',
#  'авария',
#  'авариям',
#  'авариях',
#  'аватар',
#  'аватара',
#  'аватарам',
#  'аватарами',
#  'аватаре',
#  'аватарным',
#  'аватаров',
#  'аватаром',
#  'аватары',
#  'аваш',
#  'август',
#  'августа',
#  'августе',
#  'августин',
#  'августина',
#  'августином',
#  'августовский',
#  'августом',
#  'августу',
#  'авентис',
#  'авеню',
#  'ави',
#  'авиа',
#  'авиабазе',
#  'авиабилет',
#  'авиабилеты',
#  'авиадиспетчеров',
#  'авиакатастроф',
#  'авиакатастрофе',
#  'авиакатастрофы',
#  'авиакомпанией',
#  'авиакомпании',
#  'авиакомпаний',
#  'авиакомпания',
#  'авиакосмическая',
#  'авиакосмической',
#  'авиакосмическую',
#  'авиалинией',
#  'авиалинии',
#  'авиалиний',
#  'авиалинию',
#  'авиалиния',
#  'авиалиниям',
#  'авиалиниями',
#  'авиалиниях',
#  'авиамилях',
#  'авиамоделированием',
#  'авианосец',
#  'авианосца',
#  'авианосцев',
#  'авианосцы',
#  'авиаперевозка',
#  'авиаперевозчика',
#  'авиаперелета',
#  'авиаперелётов',
#  'авиаперелёты',
#  'авиаполет',
#  'авиапромышленности',
#  'авиапространство',
#  'авиапутешествие',
#  'авиарейсы',
#  'авиасбор',
#  'авиасимуляторы',
#  'авиастроительная',
#  'авиастроительные',
#  'авиатоплива',
#  'авиатопливо',
#  'авиаторов',
#  'авиацией',
#  'авиации',
#  'авиационно',
#  'авиационного',
#  'авиационное',
#  'авиационной',
#  'авиационном',
#  'авиационные',
#  'авиационный',
#  'авиационным',
#  'авиацию',
#  'авиация',
#  'авив',
#  'авива',
#  'авиве',
#  'авивом',
#  'авиву',
#  'авиньон',
#  'авиокомпаний',
#  'авионика',
#  'авионики',
#  'авиорейсах',
#  'авирулентности',
#  'авиценна',
#  'авлаки',
#  'авогадро',
#  'аволво',
#  'авосика',
#  'авраам',
#  'авраама',
#  'аврааме',
#  'авраамические',
#  'авраамических',
#  'авраамической',
#  'аврелия',
#  'аврора',
#  'авроре',
#  'авроры',
#  'авс',
#  'австралазии',
#  'австралией',
#  'австралиец',
#  'австралии',
#  'австралийская',
#  'австралийски',
#  'австралийские',
#  'австралийский',
#  'австралийским',
#  'австралийских',
#  'австралийского',
#  'австралийское',
#  'австралийской',
#  'австралийском',
#  'австралийцам',
#  'австралийцами',
#  'австралийцах',
#  'австралийцев',
#  'австралийцы',
#  'австралию',
#  'австралия',
#  'австралопитек',
#  'австралопитека',
#  'австралопитеке',
#  'австралопитеки',
#  'австралопитеков',
#  'австралопитеком',
#  'австриец',
#  'австрии',
#  'австрийская',
#  'австрийский',
#  'австрийской',
#  'австрийском',
#  'австрийскому',
#  'австрийскую',
#  'австрию',
#  'австрия',
#  'австро',
#  'авто',
#  'автобанам',
#  'автобанах',
#  'автобанов',
#  'автобаны',
#  'автобизнесу',
#  'автобиографии',
#  'автобиографический',
#  'автобиографическим',
#  'автобиографических',
#  'автобиографическое',
#  'автобиографичную',
#  'автобиографичны',
#  'автобиографичные',
#  'автобиографию',
#  'автобиография',
#  'автобус',
#  'автобуса',
#  'автобусам',
#  'автобусами',
#  'автобусах',
#  'автобусе',
#  'автобусная',
#  'автобусного',
#  'автобусной',
#  'автобусную',
#  'автобусные',
#  'автобусный',
#  'автобусных',
#  'автобусов',
#  'автобусом',
#  'автобусы',
#  'автогонкам',
#  'автогонках',
#  'автогонки',
#  'автогонок',
#  'автогонщиков',
#  'автограф',
#  'автографами',
#  'автографов',
#  'автографом',
#  'автографы',
#  'автогрунтовка',
#  'автодизайна',
#  'автодорог',
#  'автодороги',
#  'автожиров',
#  'автожиры',
#  'автозаводы',
#  'автозаправка',
#  'автозаправку',
#  'автозаправочная',
#  'автозапчастей',
#  'автоиндустрии',
#  'автоинженеров',
#  'автокаталитическим',
#  'автокатастрофа',
#  'автокатастрофах',
#  'автокатастрофе',
#  'автокатастрофу',
#  'автокатастрофы',
#  'автократа',
#  'автократией',
#  'автократии',
#  'автократические',
#  'автокресел',
#  'автом',
#  'автома',
#  'автомагистралей',
#  'автомагистрали',
#  'автомагистраль',
#  'автомагнитоле',
#  'автомагнитолой',
#  'автомагнитолу',
#  'автомат',
#  'автомата',
#  'автоматам',
#  'автоматами',
#  'автоматах',
#  'автомате',
#  'автоматизации',
#  'автоматизацию',
#  'автоматизация',
#  'автоматизировала',
#  'автоматизирован',
#  'автоматизированная',
#  'автоматизированного',
#  'автоматизированное',
#  'автоматизированной',
#  'автоматизированном',
#  'автоматизированную',
#  'автоматизированные',
#  'автоматизированный',
#  'автоматизированным',
#  'автоматизированными',
#  'автоматизированных',
#  'автоматизировано',
#  'автоматизированы',
#  'автоматизировать',
#  'автоматика',
#  'автоматикой',
#  'автоматику',
#  'автоматическая',
#  'автоматически',
#  'автоматические',
#  'автоматический',
#  'автоматическим',
#  'автоматическими',
#  'автоматических',
#  'автоматического',
#  'автоматическое',
#  'автоматической',
#  'автоматическом',
#  'автоматическую',
#  'автоматной',
#  'автоматных',
#  'автоматов',
#  'автоматом',
#  'автоматонов',
#  'автомату',
#  'автоматы',
#  'автомехаников',
#  'автомеханической',
#  'автомобиле',
#  'автомобилей',
#  'автомобилейс',
#  'автомобилем',
#  'автомобилестроении',
#  'автомобилестроения',
#  'автомобили',
#  'автомобилиста',
#  'автомобилистов',
#  'автомобиль',
#  'автомобильная',
#  'автомобильного',
#  'автомобильное',
#  'автомобильной',
#  'автомобильном',
#  'автомобильному',
#  'автомобильную',
#  'автомобильные',
#  'автомобильный',
#  'автомобильным',
#  'автомобильных',
#  'автомобильпродолжением',
#  'автомобилю',
#  'автомобиля',
#  'автомобилядолжны',
#  'автомобиляза',
#  'автомобилям',
#  'автомобилями',
#  'автомобилях',
#  'автомойке',
#  'автомойку',
#  'автономен',
#  'автономии',
#  'автономию',
#  'автономия',
#  'автономная',
#  'автономно',
#  'автономного',
#  'автономное',
#  'автономной',
#  'автономном',
#  'автономность',
#  'автономную',
#  'автономны',
#  'автономные',
#  'автономный',
#  'автономным',
#  'автономными',
#  'автономных',
#  'автоответчик',
#  'автоответчиком',
#  'автоответы',
#  'автопарк',
#  'автопарка',
#  'автопарком',
#  'автопилот',
#  'автопилоте',
#  'автопилотом',
#  'автопортеты',
#  'автопортрет',
#  'автопортрета',
#  'автопортретов',
#  'автопортретом',
#  'автопортреты',
#  'автоприцепы',
#  'автопробег',
#  'автопроизводителей',
#  'автопроизводители',
#  'автопроизводитель',
#  'автопроизводителя',
#  'автопром',
#  'автопрома',
#  'автопромышленность',
#  'автор',
#  'автора',
#  'авторам',
#  'авторами',
#  'авторе',
#  'авторефрижераторы',
#  'авторизирована',
#  'авторизованый',
#  'авторизуетесь',
#  'авторикшам',
#  'авторикши',
#  'авторитаризм',
#  'авторитаризма',
#  'авторитаризмом',
#  'авторитарная',
#  'авторитарного',
#  'авторитарное',
#  'авторитарности',
#  'авторитарность',
#  'авторитарные',
#  'авторитарный',
#  'авторитарным',
#  'авторитарными',
#  'авторитарных',
#  'авторитет',
#  'авторитета',
#  'авторитетам',
#  'авторитете',
#  'авторитетно',
#  'авторитетности',
#  'авторитетные',
#  'авторитетным',
#  'авторитетных',
#  'авторитетов',
#  'авторитетом',
#  'авторитету',
#  'авторитеты',
#  'авторов',
#  'автором',
#  'авторские',
#  'авторский',
#  'авторским',
#  'авторскими',
#  'авторских',
#  'авторского',
#  'авторское',
#  'авторском',
#  'авторскую',
#  'авторства',
#  'авторство',
#  'авторством',
#  'автору',
#  'авторучки',
#  'авторы',
#  'авторынок',
#  'автосалон',
#  'автосалоне',
#  'автосбор',
#  'автосервис',
#  'автосервиса',
#  'автостанциях',
#  'автостолицы',
#  'автостоп',
#  'автостопом',
#  'автостопщики',
#  'автостопщиков',
#  'автостоянка',
#  'автостоянках',
#  'автостоянке',
#  'автостоянки',
#  'автостоянку',
#  'автостоянок',
#  'автостояночной',
#  'автострад',
#  'автострада',
#  'автострадами',
#  'автострадах',
#  'автостраде',
#  'автострадой',
#  'автостраду',
#  'автострады',
#  'автострахования',
#  'автотранспорта',
#  'автотранспортные',
#  'автотранспортных',
#  'автотранспортом',
#  'автотранспорту',
#  'автофермерству',
#  'автофургонов',
#  'автохтонных',
#  'авэй',
#  'аг',
#  'ага',
#  'агаву',
#  'агамемнона',
#  'агамемноном',
#  'агаре',
#  'агата',
#  'агглютинат',
#  'агенства',
#  'агенствами',
#  'агенство',
#  'агенству',
#  'агент',
#  'агента',
#  'агентам',
#  'агентами',
#  'агенте',
#  'агентов',
#  'агентом',
#  'агентств',
#  'агентства',
#  'агентствам',
#  'агентствами',
#  'агентствах',
#  'агентстве',
#  'агентство',
#  'агентством',
#  'агентству',
#  'агенту',
#  'агентурной',
#  'агентурную',
#  'агентурных',
#  'агенты',
#  'агенции',
#  'агитаторам',
#  'агитации',
#  'агитация',
#  'агитировали',
#  'агитировать',
#  'агломерацию',
#  'агнес',
#  'агнесс',
#  'агнессы',
#  'агнон',
#  'агностик',
#  'агностика',
#  'агностиками',
#  'агностиков',
#  'агностиком',
#  'агонизирующая',
#  'агонии',
#  'агонистами',
#  'агония',
#  'агора',
#  'агоре',
#  'агору',
#  'агоры',
#  'аграрная',
#  'аграрно',
#  'аграрной',
#  'аграрном',
#  'аграрному',
#  'аграрным',
#  'аграрных',
#  'агрегат',
#  'агрегате',
#  'агрегаторами',
#  'агрегаты',
#  'агрегацией',
#  'агрегированном',
#  'агрегированный',
#  'агрегировать',
#  'агрегирует',
#  'агрессивен',
#  'агрессивна',
#  'агрессивная',
#  'агрессивнее',
#  'агрессивно',
#  'агрессивное',
#  'агрессивной',
#  'агрессивности',
#  'агрессивность',
#  'агрессивную',
#  'агрессивны',
#  'агрессивные',
#  'агрессивный',
#  'агрессивным',
#  'агрессивными',
#  'агрессивных',
#  'агрессией',
#  'агрессии',
#  'агрессию',
#  'агрессия',
#  'агрессора',
#  'агрессорами',
#  'агрессоров',
#  'агрессоры',
#  'агрибизнес',
#  'агриопа',
#  'агро',
#  'агробизнеса',
#  'агрономов',
#  'агрономом',
#  'агропромышленных',
#  'агротуризм',
#  'агроферм',
#  'агрохимиком',
#  'агру',
#  'агры',
#  'агукать',
#  'агукающий',
#  'агумбе',
#  'агуста',
#  'агьаоси',
#  'ад',
#  'ада',
#  'адальгейрссон',
#  'адам',
#  'адама',
#  'адаме',
#  'адамом',
#  'адамс',
#  'адамса',
#  'адамсе',
#  'адаму',
#  'адаптацией',
#  'адаптации',
#  'адаптацию',
#  'адаптация',
#  'адаптациям',
#  'адаптивен',
#  'адаптивная',
#  'адаптивного',
#  'адаптивное',
#  'адаптивной',
#  'адаптивному',
#  'адаптивность',
#  'адаптивные',
#  'адаптивный',
#  'адаптивными',
#  'адаптировавшегося',
#  'адаптировавшихся',
#  'адаптировал',
#  'адаптировала',
#  'адаптировалась',
#  'адаптировали',
#  'адаптировались',
#  'адаптировалось',
#  'адаптировался',
#  'адаптирован',
#  'адаптирована',
#  'адаптированного',
#  'адаптированную',
#  'адаптированные',
#  'адаптированный',
#  'адаптированными',
#  'адаптированных',
#  'адаптированой',
#  'адаптированы',
#  'адаптировать',
#  'адаптироваться',
#  'адаптируем',
#  'адаптируемости',
#  'адаптируемся',
#  'адаптируемы',
#  'адаптируемые',
#  'адаптируете',
#  'адаптируетесь',
#  'адаптируется',
#  'адаптируй',
#  'адаптируют',
#  'адаптируются',
#  'адаптирующуюся',
#  'адаптируя',
#  'адвентистами',
#  'адвентистов',
#  'адвентисты',
#  'адвил',
#  'адвокат',
#  'адвоката',
#  'адвокатам',
#  'адвокатами',
#  'адвокате',
#  'адвокатов',
#  'адвокатом',
#  'адвокатские',
#  'адвокатскую',
#  'адвокату',
#  'адвокаты',
#  'адгезивным',
#  'адгезией',
#  'аддамса',
#  'аддералл',
#  'аддис',
#  'аддитивного',
#  'аддитивное',
#  'аддитивном',
#  'аде',
#  'адевайл',
#  'адейеми',
#  'адекватнее',
#  'адекватно',
#  'адекватного',
#  'адекватное',
#  'адекватной',
#  'адекватном',
#  'адекватному',
#  'адекватную',
#  'адекватны',
#  'адекватные',
#  'адекватными',
#  'адекватных',
#  'аделаида',
#  'аделаиде',
#  'аделаиды',
#  'аденауэра',
#  'аденике',
#  'аденина',
#  'аденинов',
#  'адено',
#  'аденоассоциированный',
#  'аденовируса',
#  'аденовирусом',
#  'аденского',
#  'адептом',
#  'адепты',
#  'ади',
#  'адиваси',
#  'адидас',
#  'адина',
#  'адинкра',
#  'адирондак',
#  'адичие',
#  'адковатом',
#  'админ',
#  'административно',
#  'административного',
#  'административное',
#  'административной',
#  'административном',
#  'административному',
#  'административную',
#  'административные',
#  'административный',
#  'административным',
#  'административными',
#  'административных',
#  'администратор',
#  'администратора',
#  'администраторами',
#  'администраторов',
#  'администратором',
#  'администраторы',
#  'администрацией',
#  'администрации',
#  'администрацию',
#  'администрация',
#  'администрирование',
#  'администрированию',
#  'администрирования',
#  'адмираала',
#  'адмирал',
#  'адмиралтейства',
#  'адмиралу',
#  'адольфа',
#  'адольфо',
#  'адом',
#  'адреналин',
#  'адреналина',
#  'адреналиновой',
#  'адреналином',
#  'адрес',
#  'адреса',
#  'адресам',
#  'адресами',
#  'адресат',
#  'адресата',
#  'адресатам',
#  'адресатов',
#  'адресату',
#  'адресации',
#  'адресация',
#  'адресная',
#  'адресной',
#  'адресности',
#  'адресную',
#  'адресов',
#  'адресовала',
#  'адресован',
#  'адресована',
#  'адресованная',
#  'адресованного',
#  'адресованные',
#  'адресованным',
#  'адресованных',
#  'адресовано',
#  'адресованы',
#  'адресовать',
#  'адресом',
#  'адресу',
#  'адресуется',
#  'адресую',
#  'адриа',
#  'адриан',
#  'адриана',
#  'адриану',
#  'адриатику',
#  'адриатическое',
#  'адрия',
#  'адронного',
#  'адронном',
#  'адронный',
#  'адронным',
#  'адронных',
#  'адская',
#  'адский',
#  'адскими',
#  'адских',
#  'адское',
#  'адскую',
#  'аду',
#  'адуака',
#  ...]

# %% [markdown]
# в словаре встречаются разные формы одного и того же слова:
# * 'аббревиатур',
# * 'аббревиатура',
# * 'аббревиатуре',
# * 'аббревиатурой',
# * 'аббревиатуру',
# * 'аббревиатуры'

# %%
stemmer = nltk.stem.SnowballStemmer('russian')

# %%
words = [
    'аббревиатур',
    'аббревиатура',
    'аббревиатуре',
    'аббревиатурой',
    'аббревиатуру',
    'аббревиатуры',
    'человек',
    'люди',
    'людьми'
]

# %%
[stemmer.stem(word) for word in words]
# Out:
# ['аббревиатур',
#  'аббревиатур',
#  'аббревиатур',
#  'аббревиатур',
#  'аббревиатур',
#  'аббревиатур',
#  'человек',
#  'люд',
#  'людьм']

# %%
lemmatizer = pymorphy2.MorphAnalyzer()

# %%
lemmatizer.parse('стекло')[0].normal_form
# Out:
# 'стекло'

# %%
[lemmatizer.parse(word)[0].normal_form for word in words]
# Out:
# ['аббревиатура',
#  'аббревиатура',
#  'аббревиатура',
#  'аббревиатура',
#  'аббревиатура',
#  'аббревиатура',
#  'человек',
#  'человек',
#  'человек']

# %%
lemmatizer.word_is_known('хендай')
# Out:
# False

# %%
lemmatizer.parse('хендай')
# Out:
# [Parse(word='хендай', tag=OpencorporaTag('VERB,perf,tran sing,impr,excl'), normal_form='хендать', score=0.2548476454293629, methods_stack=((<DictionaryAnalyzer>, 'дай', 843, 13), (<UnknownPrefixAnalyzer>, 'хен'))),
#  Parse(word='хендай', tag=OpencorporaTag('NOUN,anim,femn,Name plur,gent'), normal_form='хендая', score=0.2548476454293629, methods_stack=((<DictionaryAnalyzer>, 'дай', 169, 7), (<UnknownPrefixAnalyzer>, 'хен'))),
#  Parse(word='хендай', tag=OpencorporaTag('NOUN,anim,femn,Name plur,accs'), normal_form='хендая', score=0.2548476454293629, methods_stack=((<DictionaryAnalyzer>, 'дай', 169, 9), (<UnknownPrefixAnalyzer>, 'хен'))),
#  Parse(word='хендай', tag=OpencorporaTag('VERB,impf,tran sing,impr,excl'), normal_form='хендать', score=0.21883656509695293, methods_stack=((<FakeDictionary>, 'хендай', 206, 11), (<KnownSuffixAnalyzer>, 'дай'))),
#  Parse(word='хендай', tag=OpencorporaTag('NOUN,inan,masc,Sgtm,Geox sing,nomn'), normal_form='хендай', score=0.008310249307479225, methods_stack=((<FakeDictionary>, 'хендай', 42, 0), (<KnownSuffixAnalyzer>, 'дай'))),
#  Parse(word='хендай', tag=OpencorporaTag('NOUN,inan,masc,Sgtm,Geox sing,accs'), normal_form='хендай', score=0.008310249307479225, methods_stack=((<FakeDictionary>, 'хендай', 42, 3), (<KnownSuffixAnalyzer>, 'дай')))]

# %%
lemmatizer_cache = {}

def lemmatize(token):
    if lemmatizer.word_is_known(token):
        if token not in lemmatizer_cache:
            lemmatizer_cache[token] = lemmatizer.parse(token)[0].normal_form
        return lemmatizer_cache[token]
    return token

lemmatized_docs = [[lemmatize(token) for token in text] for text in tqdm_notebook(docs)]

cleared_docs = [[token for token in text if token not in stopword_set] for text in lemmatized_docs]
# Out:
# /var/folders/4r/96czjbws0jxg861vmb2f4y2r0000gq/T/ipykernel_57870/729433580.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   lemmatized_docs = [[lemmatize(token) for token in text] for text in tqdm_notebook(docs)]
#   0%|          | 0/1929 [00:00<?, ?it/s]

# %%
cleared_docs[0]
# Out:
# ['среди',
#  'весь',
#  'дефицит',
#  'беспокоить',
#  'сегодня',
#  'прежде',
#  'финансовый',
#  'экономический',
#  'большой',
#  'волновать',
#  'дефицит',
#  'политический',
#  'диалог',
#  'наш',
#  'способность',
#  'реагировать',
#  'современный',
#  'конфликт',
#  'настоящий',
#  'вид',
#  'осознавать',
#  'лежать',
#  'основа',
#  'являться',
#  'ключевой',
#  'игрок',
#  'работать',
#  'дипломат',
#  'обучить',
#  'работать',
#  'конфликт',
#  'спор',
#  'государство',
#  'поверьте',
#  'работа',
#  'хватать',
#  'торговля',
#  'разоружение',
#  'международный',
#  'отношение',
#  'картина',
#  'меняться',
#  'видеть',
#  'сцена',
#  'выходить',
#  'новое',
#  'ключевой',
#  'игрок',
#  'пренебрежительно',
#  'называть',
#  'группа',
#  'представлять',
#  'социальный',
#  'религиозный',
#  'политический',
#  'экономический',
#  'военный',
#  'реалия',
#  'весь',
#  'сила',
#  'стараться',
#  'понять',
#  'работать',
#  'правило',
#  'вступление',
#  'переговоры',
#  'говорить',
#  'говорить',
#  'найти',
#  'общий',
#  'язык',
#  'позволить',
#  'показать',
#  'график',
#  'который',
#  'отражать',
#  'характер',
#  'конфликт',
#  'год',
#  'сегодняшний',
#  'день',
#  'зелёный',
#  'цвета',
#  'традиционный',
#  'межгосударственный',
#  'конфликт',
#  'который',
#  'привыкнуть',
#  'читать',
#  'газета',
#  'красный',
#  'современный',
#  'конфликт',
#  'конфликт',
#  'внутри',
#  'государство',
#  'довольно',
#  'многообразный',
#  'находиться',
#  'вне',
#  'понимание',
#  'современный',
#  'дипломатия',
#  'главный',
#  'среди',
#  'ключевой',
#  'игрок',
#  'являться',
#  'группа',
#  'представлять',
#  'различный',
#  'интерес',
#  'внутри',
#  'страна',
#  'метод',
#  'быстро',
#  'перениматься',
#  'страна',
#  'это',
#  'касаться',
#  'весь',
#  'ещё',
#  'наблюдение',
#  'который',
#  'сделать',
#  'недавно',
#  'состоять',
#  'очень',
#  'немногий',
#  'меж',
#  'внутригосударственный',
#  'конфликт',
#  'мочь',
#  'решить',
#  'применение',
#  'военный',
#  'сила',
#  'возможно',
#  'использование',
#  'военный',
#  'метод',
#  'решить',
#  'проблема',
#  'путём',
#  'получиться',
#  'необходимый',
#  'политический',
#  'решение',
#  'сталкиваться',
#  'проблема',
#  'это',
#  'вне',
#  'традиционный',
#  'дипломатия',
#  'среди',
#  'государство',
#  'чувствоваться',
#  'нежелание',
#  'это',
#  'работать',
#  'последний',
#  'десять',
#  'год',
#  'ситуация',
#  'таков',
#  'взаимодействие',
#  'группа',
#  'опасный',
#  'идейный',
#  'политический',
#  'уровень',
#  'теракт',
#  'го',
#  'сентябрь',
#  'против',
#  'чёрный',
#  'белый',
#  'довольно',
#  'часто',
#  'группа',
#  'немедленно',
#  'объявляться',
#  'террористический',
#  'вести',
#  'переговоры',
#  'террорист',
#  'запад',
#  'точка',
#  'зрение',
#  'это',
#  'десятилетие',
#  'потерять',
#  'свой',
#  'позиция',
#  'понимать',
#  'группа',
#  'потратить',
#  'большой',
#  'время',
#  'объяснить',
#  'почему',
#  'должный',
#  'говорить',
#  'найти',
#  'контакт',
#  'наивный',
#  'мочь',
#  'весь',
#  'время',
#  'весь',
#  'разговаривать',
#  'это',
#  'уходить',
#  'необходимый',
#  'военный',
#  'вмешательство',
#  'считать',
#  'ливия',
#  'это',
#  'необходимый',
#  'афганистан',
#  'страна',
#  'рассчитывать',
#  'свой',
#  'безопасность',
#  'основываться',
#  'военный',
#  'политический',
#  'блок',
#  'это',
#  'понятно',
#  'весь',
#  'огромный',
#  'нехватка',
#  'опыт',
#  'разрешение',
#  'понимание',
#  'современный',
#  'конфликт',
#  'давать',
#  'обратиться',
#  'афганистан',
#  'год',
#  'спустя',
#  'военный',
#  'вмешательство',
#  'страна',
#  'весь',
#  'ещё',
#  'далёкий',
#  'спокойствие',
#  'ситуация',
#  'честной',
#  'очень',
#  'серьёзный',
#  'военный',
#  'вмешательство',
#  'необходимый',
#  'решать',
#  'проблема',
#  'впервые',
#  'год',
#  'приехать',
#  'афганистан',
#  'качество',
#  'министр',
#  'иностранный',
#  'дело',
#  'встретиться',
#  'командир',
#  'многонациональный',
#  'сила',
#  'сказать',
#  'министр',
#  'победа',
#  'мочь',
#  'одержать',
#  'военный',
#  'средство',
#  'лишь',
#  'необходимый',
#  'далёкий',
#  'стоять',
#  'свой',
#  'четыре',
#  'командующий',
#  'смениться',
#  'слышимый',
#  'заявление',
#  'одержать',
#  'победа',
#  'военный',
#  'метод',
#  'невозможно',
#  'военный',
#  'присутствие',
#  'необходимый',
#  'необходимый',
#  'подключить',
#  'политика',
#  'возможно',
#  'политический',
#  'решение',
#  'найти',
#  'это',
#  'решение',
#  'должный',
#  'афганец',
#  'необходимый',
#  'политический',
#  'обстановка',
#  'отличный',
#  'сложиться',
#  'метр',
#  'метр',
#  'необходимый',
#  'политика',
#  'участие',
#  'который',
#  'член',
#  'это',
#  'крайне',
#  'сложный',
#  'общество',
#  'смочь',
#  'решать',
#  'свой',
#  'проблема',
#  'вроде',
#  'весь',
#  'это',
#  'согласный',
#  'это',
#  'спорный',
#  'вопрос',
#  'четыре',
#  'пять',
#  'год',
#  'назад',
#  'сегодня',
#  'весь',
#  'согласный',
#  'готовый',
#  'разговор',
#  'осознать',
#  'мало',
#  'знать',
#  'разговаривать',
#  'понимать',
#  'происходить',
#  'международный',
#  'комитет',
#  'красный',
#  'крест',
#  'мккк',
#  'вести',
#  'переговоры',
#  'весь',
#  'нейтральный',
#  'это',
#  'причина',
#  'почему',
#  'организация',
#  'возможно',
#  'являться',
#  'наиболее',
#  'информированный',
#  'разбираться',
#  'современный',
#  'конфликт',
#  'игрок',
#  'разговаривать',
#  'считать',
#  'обязательно',
#  'нейтральный',
#  'разговаривать',
#  'обязательно',
#  'соглашаться',
#  'садиться',
#  'стол',
#  'переговоры',
#  'прервать',
#  'переговоры',
#  'разговаривать',
#  'невозможно',
#  'привлечь',
#  'сторона',
#  'сторона',
#  'который',
#  'собираться',
#  'привлечь',
#  'переговоры',
#  'оппонент',
#  'который',
#  'корн',
#  'согласный',
#  'подписание',
#  'соглашение',
#  'осло',
#  'премьер',
#  'министр',
#  'рабин',
#  'сказать',
#  'заключать',
#  'мир',
#  'свой',
#  'друг',
#  'заключать',
#  'мир',
#  'враг',
#  'это',
#  'тяжело',
#  'необходимый',
#  'позволить',
#  'продолжить',
#  'это',
#  'площадь',
#  'тахрир',
#  'революция',
#  'разгар',
#  'арабский',
#  'весна',
#  'перетекать',
#  'осень',
#  'затем',
#  'зима',
#  'это',
#  'длиться',
#  'ещё',
#  'долгий',
#  'долгий',
#  'время',
#  'знать',
#  'это',
#  'называться',
#  'конец',
#  'это',
#  'важный',
#  'важный',
#  'возможно',
#  'наблюдать',
#  'история',
#  'арабский',
#  'мир',
#  'революция',
#  'снизу',
#  'революция',
#  'народ',
#  'социальный',
#  'группа',
#  'выходить',
#  'улица',
#  'запад',
#  'осознать',
#  'обладать',
#  'очень',
#  'небольшой',
#  'знание',
#  'происходить',
#  'разговаривать',
#  'человек',
#  'страна',
#  'большинство',
#  'правительство',
#  'следовать',
#  'диктат',
#  'авторитарный',
#  'лидер',
#  'держаться',
#  'далёкий',
#  'различный',
#  'группа',
#  'являться',
#  'террорист',
#  'выходить',
#  'улица',
#  'приветствовать',
#  'демократический',
#  'революция',
#  'понимать',
#  'мало',
#  'знать',
#  'данный',
#  'момент',
#  'весь',
#  'ещё',
#  'продолжаться',
#  'дискуссия',
#  'следовать',
#  'вести',
#  'переговоры',
#  'брат',
#  'мусульманин',
#  'следовать',
#  'разговаривать',
#  'хамас',
#  'поступить',
#  'легитимировать',
#  'считать',
#  'это',
#  'ошибочный',
#  'вести',
#  'переговоры',
#  'правильный',
#  'ключ',
#  'ясно',
#  'дать',
#  'понять',
#  'разговаривать',
#  'значит',
#  'соглашаться',
#  'мочь',
#  'заявить',
#  'брат',
#  'мусульманин',
#  'следовать',
#  'сделать',
#  'обязать',
#  'уважать',
#  'право',
#  'меньшинство',
#  'принимать',
#  'право',
#  'большинство',
#  'мочь',
#  'перерасти',
#  'большинство',
#  'избежать',
#  'двойной',
#  'стандарт',
#  'пропагандировать',
#  'демократия',
#  'одновременно',
#  'желать',
#  'общаться',
#  'группа',
#  'представлять',
#  'интерес',
#  'народ',
#  'смочь',
#  'сесть',
#  'стол',
#  'переговоры',
#  'подчинённый',
#  'проинструктировать',
#  'вести',
#  'переговоры',
#  'весь',
#  'группа',
#  'переговоры',
#  'вести',
#  'разный',
#  'разграничивать',
#  'переговоры',
#  'дипломатический',
#  'политический',
#  'уровень',
#  'сегодня',
#  'переговоры',
#  'мочь',
#  'иметь',
#  'свой',
#  'цель',
#  'помощь',
#  'мочь',
#  'иметь',
#  'мочь',
#  'иметь',
#  'свой',
#  'цель',
#  'участие',
#  'мочь',
#  'иметь',
#  'существовать',
#  'масса',
#  'способ',
#  'это',
#  'работать',
#  'отказаться',
#  'переговоры',
#  'новый',
#  'группа',
#  'который',
#  'главный',
#  'тема',
#  'новость',
#  'протяжение',
#  'многий',
#  'год',
#  'усугубить',
#  'ситуация',
#  'взгляд',
#  'отказаться',
#  'насилие',
#  'польза',
#  'политика',
#  'намного',
#  'сложный',
#  'смочь',
#  'показать',
#  'это',
#  'человек',
#  'идти',
#  'навстречу',
#  'демократия',
#  'стремиться',
#  'нормальный',
#  'цивилизовать',
#  'отношение',
#  'государство',
#  'это',
#  'принести',
#  'польза',
#  'парадокс',
#  'возможно',
#  'последний',
#  'десятилетие',
#  'нисколько',
#  'продвинуться',
#  'это',
#  'вопрос',
#  'парадокс',
#  'именно',
#  'это',
#  'десятилетие',
#  'очень',
#  'многообещающий',
#  'б',
#  'ольшей',
#  'степень',
#  'причина',
#  'причина',
#  'произойти',
#  'юар',
#  'нельсон',
#  'мандела',
#  'мандела',
#  'выйти',
#  'тюрьма',
#  'год',
#  'заключение',
#  'сказать',
#  'свой',
#  'сторонник',
#  'пришлый',
#  'время',
#  'взять',
#  'рука',
#  'оружие',
#  'время',
#  'сражаться',
#  'последовать',
#  'международный',
#  'сообщество',
#  'признать',
#  'справедливо',
#  'это',
#  'право',
#  'сражаться',
#  'знаете',
#  'мандела',
#  'это',
#  'сделать',
#  'свой',
#  'автобиография',
#  'долгий',
#  'путь',
#  'свобода',
#  'писать',
#  'пережить',
#  'весь',
#  'год',
#  'заключение',
#  'убедить',
#  'воспринимать',
#  'свой',
#  'гонитель',
#  'человек',
#  'весь',
#  'человек',
#  'весь',
#  'сделать',
#  'политический',
#  'процесс',
#  'диалог',
#  'стратегия',
#  'слабый',
#  'стратегия',
#  'сильный',
#  'привлечь',
#  'человек',
#  'серьёзный',
#  'переговоры',
#  'решать',
#  'самый',
#  'запутанный',
#  'вопрос',
#  'правда',
#  'примирение',
#  'человек',
#  'просто',
#  'приходить',
#  'разговаривать',
#  'наш',
#  'южноафриканский',
#  'друг',
#  'знать',
#  'усилие',
#  'это',
#  'требовать',
#  'вывод',
#  'мочь',
#  'сделать',
#  'диалог',
#  'это',
#  'очень',
#  'нелегко',
#  'индивидуум',
#  'группа',
#  'государство',
#  'это',
#  'крайне',
#  'необходимый',
#  'собираться',
#  'работать',
#  'конфликт',
#  'политический',
#  'уровень',
#  'планировать',
#  'понять',
#  'новое',
#  'группа',
#  'который',
#  'выходить',
#  'народ',
#  'владеть',
#  'современный',
#  'технология',
#  'доступный',
#  'весь',
#  'дипломат',
#  'мочь',
#  'просто',
#  'сидеть',
#  'свой',
#  'банкет',
#  'уверенный',
#  'решать',
#  'межгосударственный',
#  'вопрос',
#  'должный',
#  'следить',
#  'перемена',
#  'должный',
#  'диалог',
#  'вступать',
#  'переговоры',
#  'действительно',
#  'надеяться',
#  'сторона',
#  'поддержать',
#  'точка',
#  'зрение',
#  'передать',
#  'свой',
#  'видение',
#  'свой',
#  'ценность',
#  'мочь',
#  'это',
#  'сделать',
#  'пока',
#  'показать',
#  'открытый',
#  'мнение',
#  'сторона',
#  'необходимый',
#  'ещё',
#  'работать',
#  'это',
#  'ещё',
#  'большой',
#  'практиковаться',
#  'метод',
#  'добиться',
#  'решение',
#  'проблема',
#  'знать',
#  'свой',
#  'опыт',
#  'зачастую',
#  'гораздо',
#  'простой',
#  'просто',
#  'уйти',
#  'приходиться',
#  'сражаться',
#  'стать',
#  'утверждать',
#  'любой',
#  'обстоятельство',
#  'это',
#  'неверный',
#  'правда',
#  'приходиться',
#  'метод',
#  'вряд',
#  'сильно',
#  'преуспеть',
#  'альтернатива',
#  'являться',
#  'стратегия',
#  'исполнение',
#  'обязательство',
#  'принципиальный',
#  'диалог',
#  'убедить',
#  'необходимый',
#  'укреплять',
#  'данный',
#  'подход',
#  'современный',
#  'дипломатия',
#  'аспект',
#  'международный',
#  'отношение',
#  'внутри',
#  'государство',
#  'видеть',
#  'изменение',
#  'подписать',
#  'конвенция',
#  'запрещение',
#  'применение',
#  'противопехотный',
#  'мина',
#  'кассетный',
#  'оружие',
#  'проводить',
#  'дипломатия',
#  'иначе',
#  'поддержка',
#  'общественный',
#  'мнение',
#  'неожиданно',
#  'член',
#  'общественный',
#  'организация',
#  'перестать',
#  'просто',
#  'выкрикивать',
#  'слоганы',
#  'улица',
#  'подключиться',
#  'переговоры',
#  'отчасти',
#  'представлять',
#  'интерес',
#  'жертва',
#  'данный',
#  'оружие',
#  'привнести',
#  'свой',
#  'знание',
#  'состояться',
#  'взаимодействие',
#  'дипломатия',
#  'сила',
#  'общественность',
#  'это',
#  'пожалуй',
#  'составлять',
#  'перемена',
#  'уверенный',
#  'будущее',
#  'следовать',
#  'приводить',
#  'большой',
#  'пример',
#  'дипломатия',
#  'переставать',
#  'являться',
#  'обособленный',
#  'народ',
#  'гражданский',
#  'общество',
#  'выходить',
#  'рамка',
#  'традиционный',
#  'дипломатия',
#  'необходимый',
#  'обратиться',
#  'вопрос',
#  'наш',
#  'выживание',
#  'вопрос',
#  'изменение',
#  'климат',
#  'возможно',
#  'решить',
#  'данный',
#  'проблема',
#  'путём',
#  'переговоры',
#  'состояние',
#  'воспринимать',
#  'гражданский',
#  'общество',
#  'простой',
#  'человек',
#  'часть',
#  'проблема',
#  'часть',
#  'решение',
#  'необходимый',
#  'политика',
#  'участие',
#  'сильно',
#  'отличаться',
#  'использовать',
#  'сегодня',
#  'дипломатия',
#  'скоро',
#  'предстоять',
#  'ещё',
#  'круг',
#  'нелёгкая',
#  'переговоры',
#  'это',
#  'случай',
#  'двигаться',
#  'превратить',
#  'это',
#  'большой',
#  'напоминать',
#  'всеобщий',
#  'мобилизация',
#  'технология',
#  'глобализация',
#  'стать',
#  'важный',
#  'понять',
#  'общество',
#  'начинать',
#  'обычный',
#  'человек',
#  'дипломат',
#  'необходимый',
#  'знать',
#  'являться',
#  'социальный',
#  'капитал',
#  'общество',
#  'заставлять',
#  'человек',
#  'доверять',
#  'друг',
#  'друг',
#  'межгосударственный',
#  'уровень',
#  'внутри',
#  'страна',
#  'легитимность',
#  'дипломатический',
#  'решение',
#  'разрабатывать',
#  'дипломат',
#  'мочь',
#  'идти',
#  'речь',
#  'это',
#  'решение',
#  'ясно',
#  'понятно',
#  'широкий',
#  'сила',
#  'общественность',
#  'который',
#  'небрежно',
#  'называть',
#  'группа',
#  'бессильный',
#  'огромный',
#  'количество',
#  'средство',
#  'коммуникация',
#  'возможность',
#  'связь',
#  'услышать',
#  'возможность',
#  'принимать',
#  'участие',
#  'дипломатия',
#  'располагать',
#  'огромный',
#  'выбор',
#  'средство',
#  'укрепление',
#  'коммуникация',
#  'проблема',
#  ...]

# %% [markdown]
# Во сколько раз уменьшился словарь после лемматизации?

# %%
len({token for text in cleared_docs for token in text})
# Out:
# 53823

# %% [markdown]
# # Выделение коллокаций
#
# Посчитайте, сколько раз пары слов встречались вместе

# %%
cooccurence = Counter([(doc[i], doc[i + 1]) for doc in docs for i in range(len(doc) - 1)])

# %%
cooccurence.most_common(20)
# Out:
# [(('потому', 'что'), 6117),
#  (('то', 'что'), 4588),
#  (('и', 'я'), 3929),
#  (('что', 'мы'), 3727),
#  (('том', 'что'), 3203),
#  (('у', 'нас'), 3117),
#  (('что', 'я'), 3065),
#  (('что', 'это'), 3014),
#  (('я', 'не'), 2867),
#  (('и', 'это'), 2840),
#  (('в', 'том'), 2826),
#  (('что', 'то'), 2608),
#  (('это', 'не'), 2507),
#  (('так', 'что'), 2496),
#  (('о', 'том'), 2455),
#  (('и', 'в'), 2448),
#  (('мы', 'можем'), 2373),
#  (('самом', 'деле'), 2358),
#  (('на', 'самом'), 2303),
#  (('в', 'этом'), 2217)]

# %% [markdown]
# $$
# PMI(x,y) = \log\frac{p\left(x,y\right)}{p\left(x\right)p\left(y\right)}
# $$
#
# $$
# p(w_i) \sim \frac{\text{count}\left(w_i\right)}{\displaystyle\sum_{j=1}^n \text{count}\left( w_j \right)} = \frac{\text{count}\left(w_i\right)}{N}
# $$
#
# $$
# PMI(w_1, w_2) \sim \log\left(\frac{N \cdot \text{count}\left(w_1, w_2\right)}{\text{count}\left(w_1\right) \text{count}\left(w_2\right) }\right)
# $$

# %% [markdown]
# постройте словарь, в котором парам слов соответствует значения pmi
#
# добавляйте в словарь только те пары слов, которые встретились в корпусе хотя бы `min_cooccur` раз

# %%
cooccurence.most_common(10)
# Out:
# [(('потому', 'что'), 6117),
#  (('то', 'что'), 4588),
#  (('и', 'я'), 3929),
#  (('что', 'мы'), 3727),
#  (('том', 'что'), 3203),
#  (('у', 'нас'), 3117),
#  (('что', 'я'), 3065),
#  (('что', 'это'), 3014),
#  (('я', 'не'), 2867),
#  (('и', 'это'), 2840)]

# %%
occurence.most_common(10)
# Out:
# [('и', 99066),
#  ('в', 88906),
#  ('что', 60461),
#  ('я', 49177),
#  ('это', 48070),
#  ('на', 41620),
#  ('не', 41373),
#  ('мы', 39265),
#  ('с', 27817),
#  ('как', 25721)]

# %% [markdown]
# если хочется автоматически выделять коллокации для извлечения признаков: [gensim.models.phrases.{Phrases, Phraser}](https://www.machinelearningplus.com/nlp/gensim-tutorial/#10howtocreatebigramsandtrigramsusingphrasermodels)
#
# ```python
# phrases = (bows, min_count=30, progress_per=500)
#
# bigram = gensim.models.phrases.Phraser(phrases)
#
# bigram[bows[0]]
# ```

# %% [markdown]
# # TF-IDF

# %% [markdown]
# ## поиск похожих

# %%
vectorizer = TfidfVectorizer(
    tokenizer=lambda x: x, lowercase=False, max_df=0.8, min_df=2, norm='l2'
).fit(cleared_docs)

# %%
TfidfVectorizer?

# %% [markdown]
# получите tf-idf векторы документов, посчитайте cosine similarity каждого документа с каждым

# %%
docs_tf_idf = vectorizer.transform(cleared_docs).toarray()

# %%
similarities = docs_tf_idf @ docs_tf_idf.T

# %%
def similar_pairs_from_matrix(similarity_matrix, threshold):
    return [
        ((i, j), similarities[i, j])
        for i in range(similarities.shape[0]) for j in range(similarities.shape[1]) 
        if j > i  and similarities[i, j] > threshold
    ]


similar_pairs = similar_pairs_from_matrix(similarities, threshold=0.1)

# %%
similar_pairs
# Out:
# [((15, 1544), 0.6140960223044711),
#  ((23, 344), 0.5931552628796589),
#  ((23, 839), 0.5984448408138686),
#  ((23, 880), 0.5333260347282172),
#  ((23, 884), 0.5826780791320673),
#  ((23, 965), 0.6830220657562046),
#  ((23, 1914), 0.6283032553607264),
#  ((73, 839), 0.5075796064873929),
#  ((73, 884), 0.5242169876101589),
#  ((73, 965), 0.6082672718548895),
#  ((73, 1914), 0.537073706131316),
#  ((74, 94), 0.7198235432651617),
#  ((74, 153), 0.5740334945524542),
#  ((74, 1905), 0.6099780364879678),
#  ((94, 153), 0.5357115634639055),
#  ((94, 1905), 0.72013529339023),
#  ((103, 1856), 0.5409078442428267),
#  ((159, 229), 0.5012873188750162),
#  ((180, 821), 0.6453553372266205),
#  ((180, 1723), 0.6999922791837121),
#  ((200, 1482), 0.719871293405039),
#  ((258, 1116), 0.5379669780709346),
#  ((276, 1713), 0.5606039912113843),
#  ((282, 1509), 0.5762458473072821),
#  ((305, 1822), 0.5480580820869935),
#  ((318, 1078), 0.5359290879316913),
#  ((331, 491), 0.5694537969711018),
#  ((331, 1041), 0.7162091829288485),
#  ((344, 839), 0.5760005712873807),
#  ((344, 880), 0.5033112550762597),
#  ((344, 884), 0.5516086217336326),
#  ((344, 965), 0.684448436730882),
#  ((344, 1914), 0.5988655555395888),
#  ((377, 1014), 0.588970715837161),
#  ((491, 565), 0.5335169774873565),
#  ((491, 812), 0.6167870658179744),
#  ((491, 1548), 0.5373153992284498),
#  ((503, 595), 0.5413375229856531),
#  ((506, 1717), 0.5727122238515172),
#  ((515, 1103), 0.6441993197710874),
#  ((519, 1211), 0.553290181803502),
#  ((553, 1655), 0.5283218743349581),
#  ((565, 812), 0.5029072488089852),
#  ((565, 1548), 0.5477962745964767),
#  ((582, 790), 0.567225221564935),
#  ((586, 1106), 0.5787346942076218),
#  ((588, 1295), 0.5080519691306169),
#  ((614, 763), 0.6640767597430131),
#  ((621, 1759), 0.5198573780017417),
#  ((630, 1543), 0.5429832149769475),
#  ((726, 868), 0.5004920500294008),
#  ((794, 1839), 0.5588776265337667),
#  ((812, 1456), 0.5326372989995047),
#  ((812, 1548), 0.6011776492640766),
#  ((812, 1697), 0.5113881831496465),
#  ((815, 1199), 0.8249961842436339),
#  ((817, 1321), 0.5286308656898534),
#  ((821, 1723), 0.6395586406734587),
#  ((839, 880), 0.5022158897097703),
#  ((839, 884), 0.5869236578345405),
#  ((839, 965), 0.7101184016240369),
#  ((839, 1914), 0.636497958216421),
#  ((842, 1913), 0.6199213659481138),
#  ((852, 1697), 0.5248133312059471),
#  ((880, 965), 0.5595069336422634),
#  ((880, 1914), 0.5038273352913017),
#  ((884, 965), 0.7020554333381619),
#  ((884, 1914), 0.6194555334707351),
#  ((896, 1822), 0.5268079571256606),
#  ((912, 1067), 0.6034434110912416),
#  ((956, 1289), 0.5976610507165713),
#  ((962, 1839), 0.5441114927197226),
#  ((965, 1372), 0.5003811702861714),
#  ((965, 1914), 0.7370566615803932),
#  ((981, 1822), 0.5328992584078355),
#  ((1035, 1431), 0.5524547506541109),
#  ((1037, 1087), 0.5084337471062593),
#  ((1094, 1879), 0.5111976474572432),
#  ((1107, 1377), 0.5069396181603344),
#  ((1108, 1777), 0.5396783190581677),
#  ((1176, 1380), 0.5952375163104006),
#  ((1200, 1805), 0.619042448189617),
#  ((1210, 1635), 0.5011219740080295),
#  ((1272, 1518), 0.5585651184326296),
#  ((1393, 1536), 0.7072735015040474),
#  ((1426, 1690), 0.6338410723965302),
#  ((1489, 1832), 0.501885156365959),
#  ((1565, 1826), 0.6549092882000371),
#  ((1803, 1812), 0.5137458581936645)]

# %%
similar_pairs = sorted(similar_pairs, key=lambda x: -x[1], reverse=True)[:10]

# %%
similar_pairs
# Out:
# [((550, 1386), 0.10000025582683736),
#  ((1500, 1659), 0.1000003663637967),
#  ((684, 1568), 0.10000052691278218),
#  ((882, 1794), 0.10000053503142416),
#  ((1432, 1707), 0.10000054480407883),
#  ((411, 1840), 0.10000073811003914),
#  ((13, 1111), 0.10000116226314036),
#  ((403, 1791), 0.10000138159388101),
#  ((183, 1915), 0.10000139983612619),
#  ((1437, 1818), 0.10000155232814252)]

# %%
def print_talks(talk_ids, text_chunk=1024):

    for talk_id in talk_ids:
        record = df.loc[talk_id]

        print(record.talk)
        print('-' * 100)
        print(record.text[:text_chunk])
        print('#' * 100)

# %%
for pair, score in similar_pairs:
    print("*" * 10)
    print(f"{score:.2f}")
    print("*" * 10)
    print_talks(pair)
# Out:
# **********
# 0.10
# **********
# al_gore_the_case_for_optimism_on_climate_change
# ----------------------------------------------------------------------------------------------------
# Я так радовался возможности выступить на конференции о мечтах , а оказалось , что я открываю в ней сессию про « Кошмары » . ( Смех ) Безусловно , климатический кризис не без кошмаров . И у меня для вас есть плохие новости , но больше новостей у меня хороших . Я поставлю три вопроса , и в ответе на первый из них неминуемо присутствуют плохие новости . Но не унывайте , так как ответы на второй и третий вопросы очень оптимистичны . Итак , первый вопрос : должны ли мы измениться ? Миссия « Аполлон » , кроме всего прочего , безусловно , изменила экологическое движение , она , по сути , создала современное экологическое движение . Спустя 18 месяцев после того , как этот рассвет увидели на Земле , был учреждён первый День Земли . Мы многое о себе узнали , глядя на нашу планету из космоса . И одна из вещей , которые мы узнали , подтвердила то , о чём нам давно говорили учёные . Один из самых важных фактов в климатическом кризисе связан с небом . На этом изображении видно , что небо — это не огромное и бескрайнее прос
# ####################################################################################################
# elise_roy_when_we_design_for_disability_we_all_benefit
# ----------------------------------------------------------------------------------------------------
# Я никогда не забуду звук смеха , когда мы хохотали с друзьями . Я никогда не забуду убаюкивающий звук голоса матери . И я никогда не забуду умиротворяющий звук воды , журчащей в ручье . Представьте себе мой страх , настоящий ужас , который я пережила , когда мне в 10 лет сказали , что я потеряю слух . В течение последующих пяти лет болезнь прогрессировала , пока мне не поставили диагноз — абсолютная глухота . Но я верю , что потеря слуха стала лучшим подарком в моей жизни . Понимаете , я получила возможность познать мир по-новому . Я работала адвокатом по правам инвалидов , и большую часть времени я следила за исполнением закона , за разрешением споров . А потом мне пришлось быстро входить в курс международной политики , так как меня пригласили участвовать в работе Конвенции ООН по защите прав людей с ограниченными возможностями . Как глава НПО , большую часть времени я посвящала тому , чтобы убедить окружающих , что люди с ограниченными возможностями мало в чём им уступают . Но в какой-то момент после всех и
# ####################################################################################################
# **********
# 0.10
# **********
# nancy_etcoff_on_happiness_and_why_we_want_it
# ----------------------------------------------------------------------------------------------------
# Это называется &quot; &quot; помешанный на чувстве &quot; &quot; : преследование счастья и дизайна , ориентированного на человека . Вверху я разместила несколько сурового Дарвина , зато шимпанзе выглядит веселым . Во-первых , преследование счастья является обязательным . Человек хочет быть счастливым , он желает только быть счастливым , и не может не желать этого . В нас заложено стремление к счастью , причем не просто к наслаждению им , но и к желанию всё больше и больше счастья . Исходя из этой истины , спросим , а насколько мы умеем преумножать наше счастье ? Пытаться-то мы пытаемся На сайте Amazon можно без труда найти свыше 2 тысяч книг , рекомендующих семь привычек , девять решений , десять секретов и 14 тысяч идей , которые , как там утверждается , принесут счастье . Есть ещё один способ попытаться увеличить ощущение счастья – глотать разные специальные пилюли . Назначений антидепрессантов , выписанных врачами , насчитывается на сегодняшний день , уже свыше 120 миллионов . Прозак &#91; Prozac &#93; ста
# ####################################################################################################
# heather_brooke_my_battle_to_expose_government_corruption
# ----------------------------------------------------------------------------------------------------
# Когда-то мир был большой неблагополучной семьёй . В ней правили величественные и могущественные родители , а люди были беспомощными и отчаявшимися непослушными детьми . Если кто-то из детей побойчее ставил под сомнение авторитет родителей , их ругали . Если любопытство заводило их в родительские комнаты или даже в тайные картотеки , их наказывали и говорили , что ради их же блага они больше никогда не должны туда заглядывать . И как-то раз появился человек со множеством коробок с секретными документами , выкраденными из родительских комнат . « Глядите , что они скрывали от вас » , — сказал он . Дети глянули и изумились . Там были карты и протоколы собраний , на которых родители разносили друг друга в пух . Вели себя прямо как дети . И они тоже совершали ошибки , совсем как дети . С той лишь разницей , что их ошибки были скрыты в тайных картотеках . И ещё была одна девочка , которая считала , что им не место в тайных картотеках , а если они и там , должен быть закон , дающий детям право доступа . И вот она взя
# ####################################################################################################
# **********
# 0.10
# **********
# laura_vanderkam_how_to_gain_control_of_your_free_time
# ----------------------------------------------------------------------------------------------------
# Когда люди узнаю ́ т , что я пишу об управлении временем , они предполагают две вещи . Первая — что я всегда всё делаю вовремя , а это не так . Иногда со мной связываются из журналов , когда пишут статью по схожим темам , обычно о том , как помочь читателям найти ещё один час в сутках . Идея в том , что мы возьмём немного времени от разных занятий , сложим его и получим много времени на другие занятия . Я сомневаюсь во всём , что касается этой идеи , но мне интересно услышать , что они придумали до того , как позвонили мне . ( Смех ) И это правда . Знаете , как ещё найти 32 минуты для упражнений ? Не смотреть телевизор по два часа , да ? Но после изучения времяпрепровождения множества успешных людей и просмотра их расписания час за часом , я думаю , эта идея должна звучать наоборот . Сохраняя время , мы не начинаем жить как хотим . Вот что я имею в виду . Я просила их отслеживать своё время за неделю , чтобы высчитать часы на работу и сон , и я поговорила с ними о стратегиях для своей книги . Если с вами когд
# ####################################################################################################
# steven_johnson_where_good_ideas_come_from
# ----------------------------------------------------------------------------------------------------
# Несколько минут назад я сделал эту фотографию примерно за 10 кварталов отсюда . Это Гранд Кафе здесь , в Оксфорде . Я сфотографировал его , потому что выяснилось , что это первая кофейня , открытая в Англии в 1650 году . Она славится своей стариной . И я захотел показать ее вам , не потому , что я хочу устроить что-то вроде Старбакс-тура по историческим местам Англии , а скорее потому , что появление кофейни в Англии послужило толчком для развития и распространения величайшей поры интеллектуального расцвета за последние 500 лет , которая называется эпохой Просвещения . Кофейня сыграла столь значимую роль в зарождении эпохи Просвещения отчасти из-за напитков , которые там употребляли . Потому что до распространения кофе и чая в британской культуре главным напитком как элиты , так и простого народа день за днем , от рассвета до заката , был алкоголь . Алкоголь был излюбленным напитком в течение дня . Немного пива на завтрак , немного вина на обед , немного джина — особенно ближе к 1650 году — и в довершение ко
# ####################################################################################################
# **********
# 0.10
# **********
# paul_knoepfler_the_ethical_dilemma_of_designer_babies
# ----------------------------------------------------------------------------------------------------
# Что , если вы , как будущий родитель , и я , как учёный , решим вместе пройти этот путь ? А если нет ? А если бы мы подумали : « Это плохая идея » , а многие наши члены семьи , друзья и коллеги приняли бы такое решение ? Давайте перенесёмся на 15 лет вперёд . Предположим , сейчас 2030 год , и вы являетесь родителем . У вас есть дочь , Марианна , и в 2030 году мы её будем называть « натуральной » , потому что её гены не были модифицированы . Вы и ваш партнёр осознанно пришли к этому решению , и многие из вашего окружения смотрят на вас сверху вниз . Они принимают вас за луддита или технофоба . А вот у Дженны , соседки и лучшей подруги Марианны , совсем другая история . Она родилась генетически модифицированным ребёнком с массой улучшений . Да-да , улучшений . Все они стали возможны благодаря технологии генетических модификаций , у неё , знаете ли , такое смешное название — CRISPR , чем-то похоже на « чипсы » , « криспры » . Родителям Дженны это обошлось в несколько миллионов долларов , они обратились за этим к
# ####################################################################################################
# linus_torvalds_the_mind_behind_linux
# ----------------------------------------------------------------------------------------------------
# Крис Андерсен : Это такое странное дело . Ваше ПО , Linux , установлено на миллионах компьютеров , оно , вероятно , основа интернета . И , я думаю , примерно полтора миллиарда устройств работают под Android . Ваше ПО — в каждом из них . Это удивительно . У вас , должно быть , удивительная штаб-квартира для всего этого . Вот что я думал — и был шокирован , увидев это . Я имею в виду — это штаб-квартира Linux . ( Смех ) ( Аплодисменты ) Линус Торвальдс : Да , выглядит не особо круто . Должен сказать , что самое интересное на этом фото , что люди чаще всего замечают , это стол для работы стоя . Это самая интересная часть моего офиса , но я вообще-то больше её не использую . Я думаю , здесь есть некая связь . Как я работаю … я не хочу никакой внешней стимуляции . Как видите , стены светло-зелёные . Мне говорили , что в психлечебницах делают такие же . ( Смех ) Это успокаивающий цвет . Он не стимулирует . Чего здесь не видно — так это компьютера , только монитор , а в компьютере меня больше всего заботит не мощнос
# ####################################################################################################
# **********
# 0.10
# **********
# chris_anderson_how_web_video_powers_global_innovation
# ----------------------------------------------------------------------------------------------------
# Может , я многого не знаю , но по крайней мере , я обнаружил через что мы заставляем пройти наших докладчиков : потные ладони , бессонные ночи и эта совершенно несвойственная человеку боязнь часов . Мне кажется , что это довольно жестоко . И вот еще , что меня беспокоит . В мире скоро будет девять миллиардов людей Самые оптимистичные мечты о будущем рушатся при мысли от том , как эти орды грабят планету . Но недавно меня заинтриговал иной подход к осмыслению функионирования больших групп людей , потому что в определенных условиях толпы могут делать и по-настоящему замечательные вещи . Это явление из которого , по моему , любая организация или отдельный человек могут извлечь пользу . Безусловно , это повлияло на то , как мы представляем себе будущее проекта TED , и , возможно , будущее мира в целом . Итак , давайте все рассмотрим по порядку . История начинается с одного человека , с ребенка , который ведет себя несколько необычно . Этот ребенок известен в интернете под прозвищем Маленький Чертенок Посмотрите ,
# ####################################################################################################
# james_balog_time_lapse_proof_of_extreme_ice_loss
# ----------------------------------------------------------------------------------------------------
# По большому счёту , искусство и наука относятся друг к другу с непониманием . Когда они пытаются навести мосты , наступает неразбериха . Несомненно , что искусство смотрит на мир через призму души , эмоций , порой неосознанных , и , конечно , эстетики . Наука склонна смотреть на мир через призму рациональных суждений и количественных величин , которые можно измерить и описать , но она обеспечивает замечательные условия для познания искусства . В рамках проекта « Экстремальное исследование льдов » мы намерены свести вместе эти две сферы человеческой деятельности , объединить искусство и науку , чтобы лучше понять природу , а также взаимоотношения человечества с природой . Например , я , человек , всю свою взрослую жизнь работающий фотографом-натуралистом , твёрдо верю , что фотография , видео и кино обладают огромной силой , способной помочь нам понять природу , повлиять на наше видение природы и себя по отношению к ней . В основе данного проекта лежит , конечно , наш интерес ко льду . Я очарован его красотой
# ####################################################################################################
# **********
# 0.10
# **********
# paul_moller_on_the_skycar
# ----------------------------------------------------------------------------------------------------
# Многие из вас задумывались над вопросом , почему летающая машина , а точнее , дорожный самолёт , стал возможным именно сейчас . Много лет тому назад мистер Форд предсказал появление летающих машин какой-нибудь конструкции . Шестьдесят лет спустя , я перед вами , чтобы рассказать , почему это возможно . Когда мне было пять лет — не более чем один год спустя сделанных мистером Фордом предсказаний , я жил в сельской части Канады , в очень изолированном месте , в предгорье . Добираться в школу , такому недоростку для своего возраста , каким был я , в канадскую зиму , было не очень-то приятно . Это было страхом и испытанием для маленького парнишки . По окончанию первого класса , летом того года , я заметил парочку колибри , застрявших в сарае рядом с моим домом . Они пытались выбраться , стучась о стекло , и их было довольно легко поймать . Я вынес их наружу , и когда я их отпустил , несмотря на усталость , они зависли на секунду в воздухе , а затем резко скрылись из виду . И я подумал : « Вот бы мне так в школу »
# ####################################################################################################
# rufus_griscom_alisa_volkman_let_s_talk_parenting_taboos
# ----------------------------------------------------------------------------------------------------
# Алиса Волкман : Итак , наша история начинается с волнующих моментов родов нашего первенца , Деклана . Очевидно , это по-настоявшему момент истины , во многом изменивший наши жизни . Некоторые из этих изменений получили необычное направление и , в результате размышлений над ними , у нас родилась идея бизнеса и год спустя мы запустили Babble , интернет-сайт для родителей . Руфус Гриском : Сейчас я думаю , что наша история началась несколькими годами раньше ( А.В. : Это правда . ) Р.Г. Возможно , ты помнишь , мы по уши влюбились друг в друга . А.В. Ага . Р.Г. : В то время мы работали над сайтом совершенно другого типа . Который назывался Nerve.com , и который был - девиз которого звучал как &quot; &quot; непристойное чтиво для образованных &quot; &quot; Теоретически , и , надеюсь , на самом деле это был продвинутый онлайн журнал о сексе и культуре . А.В. Который положил начало сайту знакомств . Представляете , какие шутки нам приходится выслушивать ? От секса получаются детки . Если вы следуете инструкциям сайта
# ####################################################################################################
# **********
# 0.10
# **********
# robin_chase_on_zipcar_and_her_next_big_idea
# ----------------------------------------------------------------------------------------------------
# Сегодня я хочу рассказать две истории . Одна о том , как ввести рыночное ценообразование , чтобы повлиять на спрос и беспроводные технологии , чтобы существенно снизить объем выхлопных газов в транспортной промышленности . В другой говорится о невероятных возможностях , при правильном выборе беспроводных технологий , произвести новый двигатель в пользу экономического роста и существенно сократить использование CO2 в других секторах . Я ужасно напугана . Мы должны уменьшить выбросы CO2 в течение 10-15 лет на 80 % , чтобы предотвратить катастрофические последствия . И меня удивляет , что я стою здесь и говорю вам это . Какие катастрофические последствия ? Изменение климата вследствие повышения температуры на три градуса , которое приведет к вымиранию 50 % видов . Это не кино . Это жизнь . И я действительно обеспокоена , потому что , когда люди говорят о машинах , - в чем я разбираюсь - журналисты и политики и все люди в этом зале думают : &quot; &quot; Давайте ездить на топливосберегающих машинах &quot; &quot;
# ####################################################################################################
# jeff_bezos_on_the_next_web_innovation
# ----------------------------------------------------------------------------------------------------
# Представлять развитие технологий и быть при этом оптимистом довольно легко . Другие выступающие сегодня , как мне стало известно , расскажут о коренных изменениях в разных сферах , но такие изменения не случаются с технологиями . Так что быть оптимистом сравнительно легче . Если мы посмотрим , что произошло в интернете за последние 6 безумных лет , то им трудно подобрать какое-то сравнение . Многое из того , как мы решаем , как относимся к событиям и чего нам ждать от будущего , зависит от оценки происходящих явлений и их категоризации . И мне кажется , что самое подходящее сравнение для взлётов и падений , которые мы видели среди интернет-компаний — Золотая лихорадка . Это сравнение значительно отличается от всех других , на которые можно указать . Прежде всего , оба явления были вполне реальными . В 1849 г. во время Золотой лихорадки более 700 миллионов долларов золота было вывезено из Калифорнии . Это было вполне реально . Интернет также был вполне реальным . Для людей это реальный способ обмена информацие
# ####################################################################################################
# **********
# 0.10
# **********
# jessica_jackley_poverty_money_and_love
# ----------------------------------------------------------------------------------------------------
# Истории , которые мы рассказываем друг другу , очень важны . Важны истории , которые мы сами рассказываем о своих жизнях . Но больше всего , на мой взгляд , то , каким образом мы участвуем в историях других , очень важно для нас . Мне было шесть лет , когда я впервые услышала рассказы о бедняках . Тогда я услышала эти рассказы не уз уст самих бедняков , а от учителя из воскресной школы и от Иисуса , говорящего с нами посредством учителя . Я помню , что усвоила то , что бедняки нуждаются в чем-то материальном : в еде , одежде , приюте - в том , чего у них нет . Кроме того , нас учили тому , что это моя работа , точнее , наша , пяти-шести-летних детей , работа - помогать . Это то , о чем просит нас Иисус . И он сказал : &quot; &quot; То , что вы делаете для них , вы делаете для меня &quot; &quot; . В то время это очень меня взволновало . Я очень стремилась быть полезной в этом мире . Думаю , у каждого из нас есть подобное желание . И к тому же , было довольно забавно , что Богу нужна наша помощь . Все это было
# ####################################################################################################
# daniel_libeskind_s_17_words_of_architectural_inspiration
# ----------------------------------------------------------------------------------------------------
# Я бы хотел начать с цитаты моей любимой музы Эмили Дикинсон , которая сказала , что стремление к познанию не есть признак понимания и не есть признак невежества . Это нечто между верой в то , чего мы можем достичь , и традициями , ушедшими в прошлое . И нахожусь под глубочайшим впечатлением , слушая выступления участников конференции . Столько потрясающих идей , столько разнообразных взглядов . И тем не менее за стенами этого здания ... посмотрите вокруг и вы увидите , как инертна архитектура , как противится она любой новизне . Мы можем создавать удивительные вещи , но когда дело касается архитектуры , нам так тяжело изменить форму стены и в итоге мы рукоплещем очередной &quot; &quot; коробке &quot; &quot; . Меня привлекает создание пространства , которое еще не было создано , не было воплощено в жизнь ; пространства , существующего только в нашем воображении . Вот в чем для меня суть архитектуры . Основа архитектруры - это не участок земли , сталь или бетон . В ее основе - желание сотворить чудо . Именно эт
# ####################################################################################################
# **********
# 0.10
# **********
# lennart_green_does_close_up_card_magic
# ----------------------------------------------------------------------------------------------------
# Я считаю , что все гениальное просто . Гений простоты это , конечно , природа . Но я покажу вам разные способы как преодолеть трудности , докопаться до истины , и найти ответы возможно , даже быстрее чем это делал Артур . Итак , во-первых , уберем в сторону здравый смысл и логику . Если вы все повернете руку вот так , горизонтально … все . Кроме вас . Все повернули ? Ладонью вверх . Когда вы это делаете логично предположить , что вы должны для этого повернуть запястье . Вы согласны ? Хорошо . Но сначала я покажу вам способ , как сделать это не поворачивая запястье. а потом объясню как это делается . Вы можете сделать это быстро , верно ? Поверните руку ладонью вверх . Не шевелите запястьем . Запястье это … Хоть я и не говорю очень много , я стараюсь делать это как можно лучше . Как будто утюгом отгладили , вы говорите ? Но это вообще-то шутка . И я … Ладно . Поверните руку ладонью вверх . Сделайте так , не поворачивая запястье . Потом вот так , не поворачивая запястье . Теперь вперед , запястьем не двигаем .
# ####################################################################################################
# tim_brown_on_creativity_and_play
# ----------------------------------------------------------------------------------------------------
# Так вот этот парень , этот парень по имени Боб МакКим . И он был исследователем креативности в 60-х и 70-х годах , а еще вел программу по дизайну в Стэнфорде . И на самом деле , мой друг и основатель IDEO , Дэвид Келли , который где-то здесь , учился под его началом в Стэнфорде . И он любил выполнять упражнение со своими студентами где они должны были взять лист бумаги и изобразить человека , сидящего рядом , своего соседа , очень быстро , настолько быстро , насколько могли . И , вообще-то , мы сейчас сделаем это упражнение . У всех вас есть куски картонки и листы бумаги . На них куча кругов . Мне нужно чтобы вы перевернули эти листки , вы должны увидеть , что они чистые с обратной стороны , окей ? И еще там должен быть карандаш . И я хочу , чтоб вы выбрали кого-нибудь сидящего рядом , и когда я скажу &quot; &quot; вперед &quot; &quot; , у вас будет 30 секунд чтобы нарисовать соседа , окей ? Так , все готовы ? Хорошо . Валяйте . У вас 30 секунд , лучше поторопиться . Давайте-давайте , ваши шедевры . Все ? Сто
# ####################################################################################################
# **********
# 0.10
# **********
# madeleine_albright_on_being_a_woman_and_a_diplomat
# ----------------------------------------------------------------------------------------------------
# Пэт Митчелл : Расскажите об этой брошке . Мадлен Олбрайт : Это разбитый &quot; &quot; стеклянный потолок &quot; &quot; . ПМ : О. Хороший выбор , я бы сказала , для TEDWomen . МО : По утрам , когда я встаю , я трачу много времени , пытаясь представить , что сегодня произойдёт . Никаких брошей не было бы , если бы не Саддам Хусейн . Я вам расскажу , как это произошло . Я поехала в ООН как посол . Это было после войны в Персидском заливе , а я была проинструктированным послом . Прекращение огня было достигнуто путём серии санкций , а я получила инструкции постоянно говорить совершенно ужасные вещи о Саддаме Хусейне , чего он , конечно , заслуживал - ведь он вторгся в чужую страну . И вдруг в газетах Багдада появилось стихотворение , в котором меня с чем только ни сравнивали , но главное - меня назвали непревзойдённой змеёй . А у меня оказалось змеиная брошь . И я надела её , когда мы обсуждали Ирак . ( смех ) И когда я вышла к журналистам , они нацелились на неё : &quot; &quot; Почему это у вас змеиная брошь ? &
# ####################################################################################################
# christiana_figueres_the_inside_story_of_the_paris_climate_agreement
# ----------------------------------------------------------------------------------------------------
# У меня есть ещё один повод для оптимизма : изменение климата . Можете мне не верить , но вот вам факт . 12 декабря 2015 года в Париже под эгидой ООН собрались представители 195 государств и единогласно — те , кто имел дело с правительствами , представляют , как это сложно , — единогласно решили целенаправленно изменить курс мировой экономики для защиты самых уязвимых и улучшить жизнь для всех нас . Это и впрямь выдающееся достижение . ( Аплодисменты ) Оно ещё больше поразит вас , если задуматься , как обстояли дела всего несколько лет назад . 2009 год , Копенгаген . Кто помнит Копенгаген ? После многих лет подготовки к соглашению по изменению климата представители тех же государств собрались в Копенгагене и потерпели фиаско . Но почему они потерпели фиаско ? По разным причинам , но в первую очередь из-за образовавшейся пропасти между « глобальным Севером » и « глобальным Югом » . И вот через шесть месяцев после этого фиаско мне было предложено продолжить работу в рамках переговоров по глобальному изменению кл
# ####################################################################################################

# %% [markdown]
# ## выделение ключевых слов

# %%
top_k = 10

# %%
doc_ids = [pair[0] for pair, threshold in similar_pairs]

# %%
features = np.array(sorted(vectorizer.vocabulary_))

# %%
[
    features[docs_tf_idf[doc_id].argsort()[::-1][:top_k]]
    for doc_id in doc_ids
]
# Out:
# [array(['муравей', 'колония', 'взаимодействие', 'поиск', 'сборщик', 'пища',
#         'алгоритм', 'муравейник', 'ресурс', 'муравьиный'], dtype='<U23'),
#  array(['робот', 'кисмет', 'игрушка', 'смех', 'внимание', 'смотреть',
#         'голос', 'итак', 'исключительность', 'общение'], dtype='<U23'),
#  array(['пчела', 'опыление', 'цветок', 'томат', 'пыльца', 'растение',
#         'улей', 'медоносный', 'пестицид', 'пчеловод'], dtype='<U23'),
#  array(['сознание', 'фундаментальный', 'закон', 'интегрирование',
#         'безумный', 'наука', 'теория', 'идея', 'поведение', 'субъективный'],
#        dtype='<U23'),
#  array(['пчела', 'клещ', 'пчелиный', 'ячейка', 'опылитель',
#         'исследователь', 'дикий', 'личинка', 'разводить', 'мёд'],
#        dtype='<U23'),
#  array(['клетка', 'орган', 'подложка', 'пациент', 'печень', 'мочевой',
#         'стволовой', 'регенерировать', 'сосуд', 'биоматериал'],
#        dtype='<U23'),
#  array(['робот', 'растение', 'сад', 'рой', 'инерция', 'столкновение',
#         'карта', 'сосед', 'пчела', 'камера'], dtype='<U23'),
#  array(['аутизм', 'ген', 'генетический', 'развитие', 'ребёнок', 'близнец',
#         'причина', 'сестра', 'случай', 'прививка'], dtype='<U23'),
#  array(['робот', 'лео', 'кисмет', 'чудовище', 'экран', 'взаимодействовать',
#         'персонаж', 'играть', 'ребёнок', 'социальный'], dtype='<U23')]

# %% [markdown]
# # Word2Vec

# %%
def prepare_sentence_dataset(documents):
    tokenized_sentences = []
    for document in tqdm_notebook(documents):
        for sentence in razdel.sentenize(document):
            lemmatized_tokens = [lemmatize(token) for token in tokenize(sentence.text)]
            tokenized_sentences.append(
                [token for token in lemmatized_tokens if token not in stopword_set]
            )
    return tokenized_sentences

sentence_dataset = prepare_sentence_dataset(corpus)
# Out:
# /var/folders/4r/96czjbws0jxg861vmb2f4y2r0000gq/T/ipykernel_57870/41998792.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for document in tqdm_notebook(documents):
#   0%|          | 0/1929 [00:00<?, ?it/s]

# %%
len(sentence_dataset)
# Out:
# 258372

# %%
sentence_dataset[0]
# Out:
# ['среди',
#  'весь',
#  'дефицит',
#  'беспокоить',
#  'сегодня',
#  'прежде',
#  'финансовый',
#  'экономический',
#  'большой',
#  'волновать',
#  'дефицит',
#  'политический',
#  'диалог',
#  'наш',
#  'способность',
#  'реагировать',
#  'современный',
#  'конфликт',
#  'настоящий',
#  'вид',
#  'осознавать',
#  'лежать',
#  'основа',
#  'являться',
#  'ключевой',
#  'игрок',
#  'работать']

# %%
word2vec = gensim.models.Word2Vec(
    vector_size=100, sg=0, window=5, min_count=5, negative=20
)

# %%
word2vec.build_vocab(sentence_dataset)

# %%
word2vec.train(sentence_dataset, total_examples=word2vec.corpus_count, epochs=30)
# Out:
# (48599524, 54499500)

# %%
word2vec.wv.most_similar('мама')
# Out:
# [('папа', 0.7077040672302246),
#  ('отец', 0.6644917130470276),
#  ('подруга', 0.6608560681343079),
#  ('муж', 0.6510631442070007),
#  ('бабушка', 0.6486673951148987),
#  ('сын', 0.6459448337554932),
#  ('дед', 0.6453324556350708),
#  ('подружка', 0.6354842782020569),
#  ('дочка', 0.6263692378997803),
#  ('жена', 0.6239577531814575)]

# %%
import tabulate
from tabulate import tabulate

test_words = ['альтруизм', 'бедность', 'платье', 'сентябрь', 'компьютер', 'лондон']

for word in test_words:
    print(word)
    print(
        tabulate(word2vec.wv.most_similar(word), tablefmt='orgtbl', headers=('neighbor', 'score')),
        end='\n\n'
    )
# Out:
# альтруизм
# | neighbor          |    score |
# |-------------------+----------|
# | сочувствие        | 0.620442 |
# | взаимозависимость | 0.558512 |
# | обоюдный          | 0.557271 |
# | сопереживание     | 0.539138 |
# | сострадание       | 0.535692 |
# | проявление        | 0.508673 |
# | духовный          | 0.49866  |
# | присущий          | 0.497983 |
# | всеобъемлющий     | 0.480461 |
# | инвестирование    | 0.478552 |
#
# бедность
# | neighbor         |    score |
# |------------------+----------|
# | нищета           | 0.771468 |
# | голод            | 0.598079 |
# | искоренение      | 0.582366 |
# | безработица      | 0.540932 |
# | искоренить       | 0.531749 |
# | неравенство      | 0.519689 |
# | коррупция        | 0.514535 |
# | малярия          | 0.512976 |
# | ликвидация       | 0.50334  |
# | несправедливость | 0.494299 |
#
# платье
# | neighbor   |    score |
# |------------+----------|
# | наряд      | 0.708326 |
# | сари       | 0.677601 |
# | одетый     | 0.67749  |
# | сапог      | 0.668859 |
# | каблук     | 0.662978 |
# | джинса     | 0.658635 |
# | рубашка    | 0.655922 |
# | смокинг    | 0.642329 |
# | футболка   | 0.641959 |
# | галстук    | 0.635419 |
#
# сентябрь
# | neighbor   |    score |
# |------------+----------|
# | май        | 0.708907 |
# | июнь       | 0.692892 |
# | январь     | 0.692735 |
# | ноябрь     | 0.668289 |
# | октябрь    | 0.663319 |
# | декабрь    | 0.658765 |
# | февраль    | 0.657236 |
# | июль       | 0.656336 |
# | март       | 0.650485 |
# | апрель     | 0.627132 |
#
# компьютер
# | neighbor       |    score |
# |----------------+----------|
# | интерфейс      | 0.604867 |
# | алгоритм       | 0.582063 |
# | калькулятор    | 0.579808 |
# | вычисление     | 0.575662 |
# | пк             | 0.568829 |
# | смартфон       | 0.563082 |
# | суперкомпьютер | 0.560378 |
# | принтер        | 0.556901 |
# | устройство     | 0.552354 |
# | аппаратный     | 0.538807 |
#
# лондон
# | neighbor   |    score |
# |------------+----------|
# | чикаго     | 0.633073 |
# | париж      | 0.629694 |
# | бостон     | 0.626444 |
# | гонконг    | 0.611929 |
# | сидней     | 0.597576 |
# | кливленд   | 0.596285 |
# | шанхай     | 0.593663 |
# | маунтин    | 0.587487 |
# | швейцария  | 0.582001 |
# | кингс      | 0.579024 |
